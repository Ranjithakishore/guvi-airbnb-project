# %%
import pymongo
import pandas as pd
import plotly.express as px
pd.set_option('display.max_columns', None)

# %%
client = pymongo.MongoClient("mongodb+srv://ranjitharavi:ranjitharavi@guviprojects.ccti9ey.mongodb.net/?retryWrites=true&w=majority&appName=guviprojects")
db = client["sample_airbnb"]
collection = db["guviAirbnbData"]

# %%
data = []

for i in collection.find({}, {"_id":1, "listing_url":1, "name":1, 'property_type':1, 'room_type':1, 'bed_type':1, 'minimum_nights':1, 'maximum_nights':1, 'cancellation_policy':1, 'accommodates':1, 'bedrooms':1, 'beds':1, 'number_of_reviews':1, 'bathrooms':1, 'price':1, 'extra_people':1, 'guests_included':1, 'images.picture_url':1, 'review_scores':1,'cleaning_fee':1}):
    data.append(i)

len(data)
# Out:
# 5555

# %%
df_1 = pd.DataFrame(data)

# %%
df_1.head()
# Out:
#         _id                            listing_url  \
# 0   1003530   https://www.airbnb.com/rooms/1003530
# 1  10133554  https://www.airbnb.com/rooms/10133554
# 2  10059872  https://www.airbnb.com/rooms/10059872
# 3  10084023  https://www.airbnb.com/rooms/10084023
# 4  10091713  https://www.airbnb.com/rooms/10091713
#
#                                                name      property_type  \
# 0               New York City - Upper West Side Apt          Apartment
# 1               Double and triple rooms Blue mosque  Bed and breakfast
# 2                Soho Cozy, Spacious and Convenient          Apartment
# 3                 City center private room with bed         Guesthouse
# 4  Surry Hills Studio - Your Perfect Base in Sydney          Apartment
#
#          room_type  bed_type minimum_nights maximum_nights  \
# 0     Private room  Real Bed             12            360
# 1     Private room  Real Bed              1           1125
# 2  Entire home/apt  Real Bed              4             20
# 3     Private room     Futon              1            500
# 4  Entire home/apt  Real Bed             10             21
#
#            cancellation_policy  accommodates  bedrooms  beds  \
# 0  strict_14_with_grace_period             2       1.0   1.0
# 1                     moderate             3       1.0   2.0
# 2                     flexible             3       1.0   2.0
# 3  strict_14_with_grace_period             1       1.0   1.0
# 4  strict_14_with_grace_period             2       0.0   1.0
#
#    number_of_reviews  bathrooms  price  cleaning_fee  extra_people  \
# 0                 70        1.0    135         135.0             0
# 1                 29        1.0    121           NaN             0
# 2                  3        1.0    699           NaN             0
# 3                 81        1.0    181          50.0           100
# 4                 64        1.0    181          50.0             0
#
#    guests_included                                             images  \
# 0                1  https://a0.muscache.com/im/pictures/15074036/a...
# 1                1  https://a0.muscache.com/im/pictures/68de30b5-e...
# 2                1  https://a0.muscache.com/im/pictures/4533a1dc-6...
# 3                1  https://a0.muscache.com/im/pictures/e6275515-7...
# 4                1  https://a0.muscache.com/im/pictures/f8eaba4e-d...
#
#    review_scores
# 0             94
# 1             92
# 2            100
# 3             92
# 4             95

# %%
df_1["images"] = df_1["images"].apply(lambda x: x["picture_url"])

# %%
df_1["review_scores"] = df_1["review_scores"].apply(lambda x: x.get("review_scores_rating", 0))

# %%
df_1.isnull().sum()
# Out:
# _id                    0
# listing_url            0
# name                   0
# property_type          0
# room_type              0
# bed_type               0
# minimum_nights         0
# maximum_nights         0
# cancellation_policy    0
# accommodates           0
# bedrooms               0
# beds                   0
# number_of_reviews      0
# bathrooms              0
# price                  0
# cleaning_fee           0
# extra_people           0
# guests_included        0
# images                 0
# review_scores          0
# dtype: int64

# %%
#handling null values
df_1["beds"] = df_1["beds"].fillna(0)
df_1["bedrooms"] = df_1["bedrooms"].fillna(0)
df_1["bathrooms"] = df_1["bathrooms"].fillna(0)
df_1["cleaning_fee"] = df_1["cleaning_fee"].fillna(0)

# %%
#changing datatype
df_1["maximum_nights"] = df_1["maximum_nights"].astype(int)
df_1["minimum_nights"] = df_1["minimum_nights"].astype(int)

df_1["beds"] = df_1["beds"].astype(int)
df_1["bedrooms"] = df_1["bedrooms"].astype(int)

df_1["bathrooms"] = df_1["bathrooms"].astype(str).astype(float).astype(int)
df_1["price"] = df_1["price"].astype(str).astype(float).astype(int)
df_1["extra_people"] = df_1["extra_people"].astype(str).astype(float).astype(int)
df_1["guests_included"] = df_1["guests_included"].astype(str).astype(float).astype(int)
df_1["cleaning_fee"] = df_1["cleaning_fee"].astype(str).astype(float).astype(int)

# %%
#Collect host details

host = []

for i in collection.find({},{"_id":1, "host":1}):
    host.append(i)

# %%
df_host = pd.DataFrame(host)

# %%
df_host["host"]
# Out:
# 0       {'host_id': '454250', 'host_url': 'https://www...
# 1       {'host_id': '52004703', 'host_url': 'https://w...
# 2       {'host_id': '51624384', 'host_url': 'https://w...
# 3       {'host_id': '51744313', 'host_url': 'https://w...
# 4       {'host_id': '13764143', 'host_url': 'https://w...
#                               ...
# 5550    {'host_id': '51303748', 'host_url': 'https://w...
# 5551    {'host_id': '51013381', 'host_url': 'https://w...
# 5552    {'host_id': '31386255', 'host_url': 'https://w...
# 5553    {'host_id': '47615848', 'host_url': 'https://w...
# 5554    {'host_id': '47092481', 'host_url': 'https://w...
# Name: host, Length: 5555, dtype: object

# %%
host_columns = {'_id':[],'host_id':[],'host_url':[],'host_name':[],'host_location':[],'host_response_time':[],
                'host_thumbnail_url':[],'host_picture_url':[],'host_neighbourhood':[],'host_response_rate':[],
                'host_is_superhost':[],'host_has_profile_pic':[],'host_identity_verified':[],'host_listings_count':[],
                'host_total_listings_count':[],'host_verifications':[]}

for i in df_host["_id"]:
    host_columns['_id'].append(i)

for i in df_host["host"]:
    host_columns['host_id'].append(i["host_id"])
    host_columns['host_url'].append(i["host_url"])
    host_columns['host_name'].append(i["host_name"])
    host_columns['host_location'].append(i["host_location"])
    host_columns['host_response_time'].append(i.get("host_response_time"))
    host_columns['host_thumbnail_url'].append(i["host_thumbnail_url"])
    host_columns['host_picture_url'].append(i["host_picture_url"])
    host_columns['host_neighbourhood'].append(i["host_neighbourhood"])
    host_columns['host_response_rate'].append(i.get("host_response_rate"))
    host_columns['host_is_superhost'].append(i["host_is_superhost"])
    host_columns['host_has_profile_pic'].append(i["host_has_profile_pic"])
    host_columns['host_identity_verified'].append(i["host_identity_verified"])
    host_columns['host_listings_count'].append(i["host_listings_count"])
    host_columns['host_total_listings_count'].append(i["host_total_listings_count"])
    host_columns['host_verifications'].append(i["host_verifications"])

# %%
df_host_2 = pd.DataFrame(host_columns)

# %%
# df_host_2
df_host_2.isnull().sum()
# Out:
# _id                             0
# host_id                         0
# host_url                        0
# host_name                       0
# host_location                   0
# host_response_time           1388
# host_thumbnail_url              0
# host_picture_url                0
# host_neighbourhood              0
# host_response_rate           1388
# host_is_superhost               0
# host_has_profile_pic            0
# host_identity_verified          0
# host_listings_count             0
# host_total_listings_count       0
# host_verifications              0
# dtype: int64

# %%
# checking the "host_neighbourhood" details

# host_neighbourhood have more empty values("")
# finding how many empty values are there

list_index = []

# %%
# host_neighbourhood have a 1923 empty values("")
# so we want to replace that empty values

# %% [markdown]
# # handling the null values and empty values for "host"

# %%
df_host_2["host_response_time"].fillna("Not Specified",inplace = True)
df_host_2["host_response_rate"].fillna("Not Specified",inplace = True)
df_host_2["host_neighbourhood"] = df_host_2["host_neighbourhood"].replace({"":"Not Specified"})
# Out:
# C:\Users\ranji\AppData\Local\Temp\ipykernel_9252\3873041375.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_host_2["host_response_time"].fillna("Not Specified",inplace = True)
# C:\Users\ranji\AppData\Local\Temp\ipykernel_9252\3873041375.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_host_2["host_response_rate"].fillna("Not Specified",inplace = True)
# C:\Users\ranji\AppData\Local\Temp\ipykernel_9252\3873041375.py:2: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Not Specified' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_host_2["host_response_rate"].fillna("Not Specified",inplace = True)

# %%
# Changing the "True" or "False" features

df_host_2["host_is_superhost"] = df_host_2["host_is_superhost"].map({False:"No", True:"Yes"})
df_host_2["host_has_profile_pic"] = df_host_2["host_has_profile_pic"].map({False:"No", True:"Yes"})
df_host_2["host_identity_verified"] = df_host_2["host_identity_verified"].map({False:"No", True:"Yes"})

# %% [markdown]
# # Collect the Address Details

# %%
address = []
for i in collection.find({},{"_id":1, "address":1}):
    address.append(i)

# %%
df_address = pd.DataFrame(address)
df_address
# Out:
#            _id                                            address
# 0      1003530  {'street': 'New York, NY, United States', 'sub...
# 1     10133554  {'street': 'Fatih , İstanbul, Turkey', 'suburb...
# 2     10059872  {'street': 'Hong Kong, Hong Kong Island, Hong ...
# 3     10084023  {'street': 'Hong Kong , 九龍, Hong Kong', 'subur...
# 4     10091713  {'street': 'Surry Hills, NSW, Australia', 'sub...
# ...        ...                                                ...
# 5550   9985696  {'street': 'Kadıköy, İstanbul, Turkey', 'subur...
# 5551   9993190  {'street': 'Lahaina, HI, United States', 'subu...
# 5552   9887054  {'street': 'Hong Kong, Hong Kong Island, Hong ...
# 5553   9907907  {'street': 'Bondi Beach, NSW, Australia', 'sub...
# 5554   9936016  {'street': 'Rio de Janeiro, Rio de Janeiro, Br...
#
# [5555 rows x 2 columns]

# %%
address_columns = {'_id':[],'street':[],'suburb':[],'government_area':[],'market':[],'country':[],
                   'country_code':[],'location_type':[],"longitude":[],"latitude":[],
                   'is_location_exact':[]}

for i in df_address["_id"]:
    address_columns['_id'].append(i)

for i in df_address["address"]:
    address_columns['street'].append(i["street"])
    address_columns['suburb'].append(i["suburb"])
    address_columns['government_area'].append(i["government_area"])
    address_columns['market'].append(i["market"])
    address_columns['country'].append(i["country"])
    address_columns['country_code'].append(i["country_code"])
    address_columns['location_type'].append(i["location"]["type"])
    address_columns["longitude"].append(i["location"]["coordinates"][0])
    address_columns["latitude"].append(i["location"]["coordinates"][1])
    address_columns['is_location_exact'].append(i["location"]["is_location_exact"])

# %%
df_address_1 = pd.DataFrame(address_columns)

# %% [markdown]
# # empty values handling

# %%
df_address_1["suburb"] = df_address_1["suburb"].replace({"":"Not Specified"})
df_address_1["market"] = df_address_1["market"].replace({"":"Not Specified"})
df_address_1["is_location_exact"] = df_address_1["is_location_exact"].map({False:"No", True:"Yes"})

# %% [markdown]
# # Availability

# %%
availability = []
for i in collection.find({},{"_id":1, "availability":1}):
    availability.append(i)

df_availability = pd.DataFrame(availability)

# %%
available_columns = {'_id':[],'availability_30':[],'availability_60':[],'availability_90':[], 'availability_365':[]}

# %%
for i in df_availability["_id"]:
    available_columns["_id"].append(i)

# %%
for i in df_availability["availability"]:
    available_columns['availability_30'].append(i["availability_30"])
    available_columns['availability_60'].append(i["availability_60"])
    available_columns['availability_90'].append(i["availability_90"])
    available_columns['availability_365'].append(i["availability_365"])

# %%
df_available_1 = pd.DataFrame(available_columns)

# %% [markdown]
# # Collecting the Amenities

# %%
df_available_1.dtypes
# Out:
# _id                 object
# availability_30      int64
# availability_60      int64
# availability_90      int64
# availability_365     int64
# dtype: object

# %%
amenities = []

for i in collection.find({},{"_id":1, "amenities":1}):
    amenities.append(i)

# %%
(amenities)
# Out:
# [{'_id': '1003530',
#   'amenities': ['Air conditioning',
#    'Buzzer/wireless intercom',
#    'Dryer',
#    'Elevator',
#    'Family/kid friendly',
#    'Heating',
#    'Internet',
#    'Kitchen',
#    'Washer',
#    'Wifi',
#    'translation missing: en.hosting_amenity_50']},
#  {'_id': '10133554',
#   'amenities': ['Air conditioning',
#    'Building staff',
#    'Dryer',
#    'Essentials',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'Free parking on premises',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Internet',
#    'Iron',
#    'Laptop friendly workspace',
#    'Self check-in',
#    'Shampoo',
#    'Smoking allowed',
#    'Suitable for events',
#    'Washer',
#    'Wifi']},
#  {'_id': '10059872',
#   'amenities': ['24-hour check-in',
#    'Air conditioning',
#    'Doorman',
#    'Elevator',
#    'Essentials',
#    'Family/kid friendly',
#    'Heating',
#    'Kitchen',
#    'Smoking allowed',
#    'translation missing: en.hosting_amenity_50']},
#  {'_id': '10084023',
#   'amenities': ['Air conditioning',
#    'Dishes and silverware',
#    'Elevator',
#    'First aid kit',
#    'Hair dryer',
#    'Hangers',
#    'Host greets you',
#    'Hot water',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Long term stays allowed',
#    'Microwave',
#    'Refrigerator',
#    'Stove',
#    'TV',
#    'Wifi']},
#  {'_id': '10091713',
#   'amenities': ['Bed linens',
#    'Dryer',
#    'Elevator',
#    'Essentials',
#    'Ethernet connection',
#    'Heating',
#    'Hot water',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Other',
#    'Shampoo',
#    'Smoke detector',
#    'TV',
#    'Washer',
#    'Wifi',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50']},
#  {'_id': '10112159',
#   'amenities': ['Cable TV',
#    'Essentials',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'Hair dryer',
#    'Hangers',
#    'Hot water',
#    'Lock on bedroom door',
#    'Long term stays allowed',
#    'Other',
#    'Shampoo',
#    'Smoke detector',
#    'TV',
#    'Wifi']},
#  {'_id': '10096773',
#   'amenities': ['Carbon monoxide detector',
#    'Essentials',
#    'Fire extinguisher',
#    'Heating',
#    'Internet',
#    'Kitchen',
#    'Smoke detector',
#    'TV',
#    'Wifi']},
#  {'_id': '10140368',
#   'amenities': ['Carbon monoxide detector',
#    'Essentials',
#    'Family/kid friendly',
#    'Free street parking',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Host greets you',
#    'Hot water',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Lock on bedroom door',
#    'Private entrance',
#    'Shampoo',
#    'Smoke detector',
#    'Wifi',
#    'translation missing: en.hosting_amenity_50']},
#  {'_id': '10021707',
#   'amenities': ['Air conditioning',
#    'Buzzer/wireless intercom',
#    'Carbon monoxide detector',
#    'Essentials',
#    'Heating',
#    'Internet',
#    'Kitchen',
#    'Lock on bedroom door',
#    'Smoke detector',
#    'Wifi']},
#  {'_id': '10038496',
#   'amenities': ['Air conditioning',
#    'Bed linens',
#    'Buzzer/wireless intercom',
#    'Cable TV',
#    'Coffee maker',
#    'Dishes and silverware',
#    'Doorman',
#    'Elevator',
#    'Essentials',
#    'Extra pillows and blankets',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'Hair dryer',
#    'Hangers',
#    'Host greets you',
#    'Hot water',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Long term stays allowed',
#    'Microwave',
#    'Oven',
#    'Paid parking off premises',
#    'Refrigerator',
#    'Smoking allowed',
#    'Stove',
#    'TV',
#    'Washer',
#    'Wide hallway clearance',
#    'Wifi']},
#  {'_id': '10059244',
#   'amenities': ['Bed linens',
#    'Essentials',
#    'Free parking on premises',
#    'Heating',
#    'Hot water',
#    'Internet',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Shampoo',
#    'Smoke detector',
#    'TV',
#    'Washer',
#    'Wifi']},
#  {'_id': '10116578',
#   'amenities': ['24-hour check-in',
#    'Air conditioning',
#    'Buzzer/wireless intercom',
#    'Cable TV',
#    'Doorman',
#    'Elevator',
#    'Family/kid friendly',
#    'Free parking on premises',
#    'Iron',
#    'Kitchen',
#    'Washer',
#    'Wheelchair accessible',
#    'Wifi']},
#  {'_id': '10009999',
#   'amenities': ['Buzzer/wireless intercom',
#    'Essentials',
#    'Family/kid friendly',
#    'First aid kit',
#    'Free parking on premises',
#    'Hair dryer',
#    'Hangers',
#    'Hot tub',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Smoking allowed',
#    'Washer',
#    'Wheelchair accessible',
#    'Wifi']},
#  {'_id': '10066928',
#   'amenities': ['Dryer',
#    'Essentials',
#    'Family/kid friendly',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Shampoo',
#    'Washer',
#    'Wifi']},
#  {'_id': '10115921',
#   'amenities': ['24-hour check-in',
#    'Air conditioning',
#    'Building staff',
#    'Buzzer/wireless intercom',
#    'Cable TV',
#    'Carbon monoxide detector',
#    'Crib',
#    'Doorman',
#    'Dryer',
#    'Elevator',
#    'Essentials',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'First aid kit',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Hot water',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Long term stays allowed',
#    'Luggage dropoff allowed',
#    'Paid parking off premises',
#    'Safety card',
#    'Self check-in',
#    'Shampoo',
#    'Smoke detector',
#    'Smoking allowed',
#    'Suitable for events',
#    'TV',
#    'Wheelchair accessible',
#    'Wifi']},
#  {'_id': '10083468',
#   'amenities': ['Accessible-height bed',
#    'Bed linens',
#    'Cable TV',
#    'Coffee maker',
#    'Cooking basics',
#    'Dishes and silverware',
#    'Essentials',
#    'Extra pillows and blankets',
#    'Fire extinguisher',
#    'First aid kit',
#    'Hair dryer',
#    'Handheld shower head',
#    'Hangers',
#    'Hot water',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Long term stays allowed',
#    'Microwave',
#    'Paid parking on premises',
#    'Refrigerator',
#    'Smoking allowed',
#    'Step-free access',
#    'Step-free access',
#    'Step-free access',
#    'Stove',
#    'TV',
#    'Well-lit path to entrance',
#    'Wide clearance to bed',
#    'Wifi',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50']},
#  {'_id': '10117617',
#   'amenities': ['Bathtub',
#    'Beachfront',
#    'Buzzer/wireless intercom',
#    'Elevator',
#    'Essentials',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'First aid kit',
#    'Hangers',
#    'Heating',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Safety card',
#    'Shampoo',
#    'TV',
#    'Washer',
#    'translation missing: en.hosting_amenity_49']},
#  {'_id': '10133350',
#   'amenities': ['Air conditioning',
#    'Buzzer/wireless intercom',
#    'Cable TV',
#    'Essentials',
#    'Family/kid friendly',
#    'Hair dryer',
#    'Heating',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Pets allowed',
#    'Pets live on this property',
#    'Shampoo',
#    'TV',
#    'Wifi']},
#  {'_id': '10051164',
#   'amenities': ['Air conditioning',
#    'Cable TV',
#    'Essentials',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'First aid kit',
#    'Internet',
#    'Kitchen',
#    'Smoking allowed',
#    'TV',
#    'Wifi']},
#  {'_id': '10082307',
#   'amenities': ['Air conditioning',
#    'Doorman',
#    'Elevator',
#    'Family/kid friendly',
#    'Hair dryer',
#    'Hangers',
#    'Internet',
#    'Iron',
#    'Shampoo',
#    'TV',
#    'Wheelchair accessible',
#    'Wifi']},
#  {'_id': '10069642',
#   'amenities': ['Air conditioning',
#    'Buzzer/wireless intercom',
#    'Cable TV',
#    'Doorman',
#    'Elevator',
#    'Essentials',
#    'Family/kid friendly',
#    'Free parking on premises',
#    'Gym',
#    'Hair dryer',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'TV',
#    'Washer',
#    'Wheelchair accessible',
#    'Wifi']},
#  {'_id': '10108388',
#   'amenities': ['Air conditioning',
#    'Bed linens',
#    'Building staff',
#    'Carbon monoxide detector',
#    'Cleaning before checkout',
#    'Coffee maker',
#    'Cooking basics',
#    'Dishes and silverware',
#    'Dishwasher',
#    'Dryer',
#    'Elevator',
#    'Essentials',
#    'Extra pillows and blankets',
#    'Fire extinguisher',
#    'First aid kit',
#    'Flat path to front door',
#    'Gym',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Hot water',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Microwave',
#    'Oven',
#    'Patio or balcony',
#    'Pool',
#    'Private living room',
#    'Refrigerator',
#    'Self check-in',
#    'Shampoo',
#    'Smoke detector',
#    'Step-free access',
#    'Step-free access',
#    'Stove',
#    'TV',
#    'Washer',
#    'Well-lit path to entrance',
#    'Wifi',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50']},
#  {'_id': '10082422',
#   'amenities': ['Elevator',
#    'Hair dryer',
#    'Heating',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Shampoo',
#    'Washer',
#    'Wifi']},
#  {'_id': '10120414',
#   'amenities': ['24-hour check-in',
#    'Air conditioning',
#    'Buzzer/wireless intercom',
#    'Dryer',
#    'Essentials',
#    'Family/kid friendly',
#    'Hair dryer',
#    'Hangers',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Shampoo',
#    'TV',
#    'Washer',
#    'Wifi']},
#  {'_id': '10138784',
#   'amenities': ['Air conditioning',
#    'Bed linens',
#    'Buzzer/wireless intercom',
#    'Dog(s)',
#    'Elevator',
#    'Essentials',
#    'First aid kit',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Host greets you',
#    'Hot water',
#    'Internet',
#    'Other pet(s)',
#    'Pets live on this property',
#    'Shampoo',
#    'Wifi',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50']},
#  {'_id': '10030955',
#   'amenities': ['24-hour check-in',
#    'Air conditioning',
#    'Buzzer/wireless intercom',
#    'Cable TV',
#    'Doorman',
#    'Elevator',
#    'Essentials',
#    'Family/kid friendly',
#    'Free parking on premises',
#    'Gym',
#    'Internet',
#    'Kitchen',
#    'Pool',
#    'TV',
#    'Washer',
#    'Wifi']},
#  {'_id': '10006546',
#   'amenities': ['Bed linens',
#    'Buzzer/wireless intercom',
#    'Cable TV',
#    'Cleaning before checkout',
#    'Coffee maker',
#    'Cooking basics',
#    'Dishes and silverware',
#    'Dishwasher',
#    'Essentials',
#    'Extra pillows and blankets',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'First aid kit',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Hot water',
#    'Iron',
#    'Kitchen',
#    'Microwave',
#    'Oven',
#    'Pack ’n Play/travel crib',
#    'Paid parking off premises',
#    'Pets allowed',
#    'Refrigerator',
#    'Room-darkening shades',
#    'Smoking allowed',
#    'Stove',
#    'TV',
#    'Washer',
#    'Waterfront',
#    'Wifi']},
#  {'_id': '10047964',
#   'amenities': ['24-hour check-in',
#    'Cable TV',
#    'Cat(s)',
#    'Essentials',
#    'Family/kid friendly',
#    'Free parking on premises',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Pets allowed',
#    'Pets live on this property',
#    'Shampoo',
#    'TV',
#    'Washer',
#    'Wifi']},
#  {'_id': '1001265',
#   'amenities': ['Air conditioning',
#    'BBQ grill',
#    'Bed linens',
#    'Cable TV',
#    'Coffee maker',
#    'Cooking basics',
#    'Disabled parking spot',
#    'Dishes and silverware',
#    'Dryer',
#    'Elevator',
#    'Essentials',
#    'Ethernet connection',
#    'Extra pillows and blankets',
#    'Free parking on premises',
#    'Garden or backyard',
#    'Hair dryer',
#    'Hangers',
#    'Hot tub',
#    'Hot water',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Lockbox',
#    'Microwave',
#    'Pool',
#    'Refrigerator',
#    'Self check-in',
#    'Shampoo',
#    'Step-free access',
#    'Step-free access',
#    'Stove',
#    'TV',
#    'Washer',
#    'Well-lit path to entrance',
#    'Wide clearance to bed',
#    'Wifi']},
#  {'_id': '10116256',
#   'amenities': ['24-hour check-in',
#    'Air conditioning',
#    'Building staff',
#    'Buzzer/wireless intercom',
#    'Carbon monoxide detector',
#    'Doorman',
#    'Dryer',
#    'Elevator',
#    'Essentials',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Hot water',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Long term stays allowed',
#    'Luggage dropoff allowed',
#    'Paid parking off premises',
#    'Self check-in',
#    'Shampoo',
#    'Smoke detector',
#    'Smoking allowed',
#    'Suitable for events',
#    'TV',
#    'Washer',
#    'Wheelchair accessible',
#    'Wifi']},
#  {'_id': '10109896',
#   'amenities': ['Air conditioning',
#    'Buzzer/wireless intercom',
#    'Cable TV',
#    'Dryer',
#    'Essentials',
#    'Family/kid friendly',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Shampoo',
#    'Smoke detector',
#    'TV',
#    'Washer',
#    'Wifi']},
#  {'_id': '10057447',
#   'amenities': ['24-hour check-in',
#    'Dryer',
#    'Essentials',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'First aid kit',
#    'Hangers',
#    'Heating',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Safety card',
#    'Shampoo',
#    'Smoke detector',
#    'Washer',
#    'Wifi']},
#  {'_id': '10057826',
#   'amenities': ['24-hour check-in',
#    'Air conditioning',
#    'Cable TV',
#    'Carbon monoxide detector',
#    'Doorman',
#    'Dryer',
#    'Elevator',
#    'Essentials',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'First aid kit',
#    'Gym',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Shampoo',
#    'Smoke detector',
#    'TV',
#    'Washer',
#    'Wifi']},
#  {'_id': '10092679',
#   'amenities': ['Bed linens',
#    'Breakfast',
#    'Cat(s)',
#    'Coffee maker',
#    'Cooking basics',
#    'Dishwasher',
#    'Essentials',
#    'Extra pillows and blankets',
#    'Free street parking',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Host greets you',
#    'Hot water',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Lock on bedroom door',
#    'Luggage dropoff allowed',
#    'Patio or balcony',
#    'Pets live on this property',
#    'Refrigerator',
#    'Shampoo',
#    'Smoking allowed',
#    'Washer',
#    'Wifi']},
#  {'_id': '10228731',
#   'amenities': ['Family/kid friendly',
#    'Free parking on premises',
#    'Internet',
#    'Kitchen',
#    'Washer',
#    'Wifi']},
#  {'_id': '1019168',
#   'amenities': ['BBQ grill',
#    'Cat(s)',
#    'Coffee maker',
#    'Cooking basics',
#    'Dishes and silverware',
#    'Dryer',
#    'Essentials',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'First aid kit',
#    'Free street parking',
#    'Garden or backyard',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Hot water',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Lockbox',
#    'Long term stays allowed',
#    'Luggage dropoff allowed',
#    'Microwave',
#    'Oven',
#    'Paid parking off premises',
#    'Pets live on this property',
#    'Refrigerator',
#    'Self check-in',
#    'Shampoo',
#    'Smoke detector',
#    'Stove',
#    'TV',
#    'Washer',
#    'Wifi']},
#  {'_id': '10240767',
#   'amenities': ['Air conditioning',
#    'BBQ grill',
#    'Bed linens',
#    'Cat(s)',
#    'Children’s books and toys',
#    'Cleaning before checkout',
#    'Coffee maker',
#    'Cooking basics',
#    'Dishes and silverware',
#    'Dryer',
#    'Essentials',
#    'Extra pillows and blankets',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'First aid kit',
#    'Free parking on premises',
#    'Garden or backyard',
#    'Hair dryer',
#    'Hangers',
#    'Host greets you',
#    'Hot water',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Long term stays allowed',
#    'Luggage dropoff allowed',
#    'Microwave',
#    'Oven',
#    'Patio or balcony',
#    'Pets live on this property',
#    'Refrigerator',
#    'Shampoo',
#    'Smoke detector',
#    'Stove',
#    'Suitable for events',
#    'TV',
#    'Washer',
#    'Wifi']},
#  {'_id': '1022200',
#   'amenities': ['Air conditioning',
#    'Cable TV',
#    'Dryer',
#    'Family/kid friendly',
#    'Free parking on premises',
#    'Gym',
#    'Internet',
#    'Kitchen',
#    'Pool',
#    'Washer',
#    'Wifi']},
#  {'_id': '10227000',
#   'amenities': ['24-hour check-in',
#    'Air conditioning',
#    'Buzzer/wireless intercom',
#    'Cable TV',
#    'Carbon monoxide detector',
#    'Doorman',
#    'Dryer',
#    'Elevator',
#    'Essentials',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'First aid kit',
#    'Free parking on premises',
#    'Gym',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Hot tub',
#    'Indoor fireplace',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Pool',
#    'Safety card',
#    'Smoke detector',
#    'Suitable for events',
#    'TV',
#    'Washer',
#    'Wheelchair accessible',
#    'Wifi']},
#  {'_id': '10186755',
#   'amenities': ['24-hour check-in',
#    'Air conditioning',
#    'Doorman',
#    'Elevator',
#    'Essentials',
#    'Family/kid friendly',
#    'Hair dryer',
#    'Heating',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'TV',
#    'Washer',
#    'Wifi']},
#  {'_id': '10141950',
#   'amenities': ['Air conditioning',
#    'Buzzer/wireless intercom',
#    'Dryer',
#    'Elevator',
#    'Essentials',
#    'Hair dryer',
#    'Heating',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'TV',
#    'Washer',
#    'Wifi']},
#  {'_id': '10184012',
#   'amenities': ['Air conditioning',
#    'Buzzer/wireless intercom',
#    'Doorman',
#    'Elevator',
#    'Essentials',
#    'Family/kid friendly',
#    'Free parking on premises',
#    'Hangers',
#    'Iron',
#    'Kitchen',
#    'Washer']},
#  {'_id': '10233856',
#   'amenities': ['Air conditioning',
#    'Doorman',
#    'Elevator',
#    'Essentials',
#    'Family/kid friendly',
#    'Hair dryer',
#    'Hangers',
#    'Lock on bedroom door',
#    'Smoke detector',
#    'TV',
#    'Wifi']},
#  {'_id': '10215858',
#   'amenities': ['Air conditioning',
#    'Doorman',
#    'Elevator',
#    'Essentials',
#    'Family/kid friendly',
#    'Hair dryer',
#    'Hangers',
#    'Lock on bedroom door',
#    'Smoke detector',
#    'TV',
#    'Wifi']},
#  {'_id': '10199760',
#   'amenities': ['Carbon monoxide detector',
#    'Dryer',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'First aid kit',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Shampoo',
#    'Smoke detector',
#    'TV',
#    'Washer',
#    'Wifi']},
#  {'_id': '10201975',
#   'amenities': ['24-hour check-in',
#    'Air conditioning',
#    'Buzzer/wireless intercom',
#    'Cable TV',
#    'Doorman',
#    'Dryer',
#    'Elevator',
#    'Essentials',
#    'Family/kid friendly',
#    'Free parking on premises',
#    'Hair dryer',
#    'Hangers',
#    'Host greets you',
#    'Hot water',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Long term stays allowed',
#    'Luggage dropoff allowed',
#    'Shampoo',
#    'Smoking allowed',
#    'TV',
#    'Washer',
#    'Wifi']},
#  {'_id': '10213499',
#   'amenities': ['Bed linens',
#    'Cable TV',
#    'Dog(s)',
#    'Essentials',
#    'Ethernet connection',
#    'Extra pillows and blankets',
#    'First aid kit',
#    'Free parking on premises',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Hot water',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Pets live on this property',
#    'Pool',
#    'Shampoo',
#    'TV',
#    'Washer',
#    'Wifi']},
#  {'_id': '10264100',
#   'amenities': ['Air conditioning',
#    'Bed linens',
#    'Buzzer/wireless intercom',
#    'Cable TV',
#    'Coffee maker',
#    'Cooking basics',
#    'Dishes and silverware',
#    'Doorman',
#    'Elevator',
#    'Essentials',
#    'Extra pillows and blankets',
#    'Family/kid friendly',
#    'First aid kit',
#    'Hair dryer',
#    'Hangers',
#    'Host greets you',
#    'Hot water',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Long term stays allowed',
#    'Microwave',
#    'Oven',
#    'Paid parking off premises',
#    'Refrigerator',
#    'Stove',
#    'TV',
#    'Washer',
#    'Wifi',
#    'Window guards',
#    'translation missing: en.hosting_amenity_50']},
#  {'_id': '10209136',
#   'amenities': ['Dryer',
#    'Essentials',
#    'Family/kid friendly',
#    'First aid kit',
#    'Free parking on premises',
#    'Heating',
#    'Internet',
#    'Kitchen',
#    'Washer',
#    'Wifi']},
#  {'_id': '10220130',
#   'amenities': ['Air conditioning',
#    'Buzzer/wireless intercom',
#    'Cable TV',
#    'Doorman',
#    'Dryer',
#    'Elevator',
#    'Essentials',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'Free parking on premises',
#    'Gym',
#    'Hangers',
#    'Hot tub',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Pool',
#    'Safety card',
#    'TV',
#    'Washer',
#    'Wifi',
#    'translation missing: en.hosting_amenity_50']},
#  {'_id': '10166986',
#   'amenities': ['24-hour check-in',
#    'Air conditioning',
#    'Buzzer/wireless intercom',
#    'Doorman',
#    'Dryer',
#    'Elevator',
#    'Essentials',
#    'Family/kid friendly',
#    'Gym',
#    'Hangers',
#    'Heating',
#    'Hot tub',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Pool',
#    'Smoke detector',
#    'TV',
#    'Washer',
#    'Wheelchair accessible',
#    'Wifi']},
#  {'_id': '10166883',
#   'amenities': ['24-hour check-in',
#    'Air conditioning',
#    'Buzzer/wireless intercom',
#    'Carbon monoxide detector',
#    'Cooking basics',
#    'Dishes and silverware',
#    'Essentials',
#    'Free street parking',
#    'Hair dryer',
#    'Heating',
#    'Hot water',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Microwave',
#    'Other',
#    'Oven',
#    'Paid parking off premises',
#    'Refrigerator',
#    'Shampoo',
#    'Single level home',
#    'Smoke detector',
#    'Stove',
#    'TV',
#    'Wifi',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50']},
#  {'_id': '1016739',
#   'amenities': ['24-hour check-in',
#    'Doorman',
#    'Dryer',
#    'Essentials',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'Free street parking',
#    'Hair dryer',
#    'Hangers',
#    'Hot water',
#    'Internet',
#    'Iron',
#    'Keypad',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Lock on bedroom door',
#    'Safety card',
#    'Self check-in',
#    'Smoke detector',
#    'Smoking allowed',
#    'TV',
#    'Washer',
#    'Wifi']},
#  {'_id': '10295352',
#   'amenities': ['Air conditioning',
#    'Buzzer/wireless intercom',
#    'Cable TV',
#    'Doorman',
#    'Elevator',
#    'Family/kid friendly',
#    'Iron',
#    'Smoking allowed',
#    'Washer',
#    'Wheelchair accessible',
#    'Wifi']},
#  {'_id': '10267144',
#   'amenities': ['24-hour check-in',
#    'Air conditioning',
#    'Breakfast',
#    'Cable TV',
#    'Doorman',
#    'Elevator',
#    'Essentials',
#    'First aid kit',
#    'Free street parking',
#    'Hair dryer',
#    'Hangers',
#    'Host greets you',
#    'Hot water',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Long term stays allowed',
#    'Luggage dropoff allowed',
#    'Pool',
#    'Shampoo',
#    'Smoking allowed',
#    'TV',
#    'Washer',
#    'Wifi']},
#  {'_id': '10266175',
#   'amenities': ['24-hour check-in',
#    'Air conditioning',
#    'Cable TV',
#    'Carbon monoxide detector',
#    'Dryer',
#    'Elevator',
#    'Essentials',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'Hair dryer',
#    'Hangers',
#    'Hot water',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Long term stays allowed',
#    'Other',
#    'Paid parking on premises',
#    'Pool',
#    'Shampoo',
#    'Smoke detector',
#    'TV',
#    'Washer',
#    'Wifi']},
#  {'_id': '10299095',
#   'amenities': ['Cat(s)',
#    'Dryer',
#    'Elevator',
#    'Essentials',
#    'Fire extinguisher',
#    'Kitchen',
#    'Pets live on this property',
#    'TV',
#    'Washer',
#    'Wifi',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50']},
#  {'_id': '103161',
#   'amenities': ['24-hour check-in',
#    'Air conditioning',
#    'Bed linens',
#    'Carbon monoxide detector',
#    'Coffee maker',
#    'Cooking basics',
#    'Dishes and silverware',
#    'Essentials',
#    'Ethernet connection',
#    'Extra pillows and blankets',
#    'First aid kit',
#    'Free street parking',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Hot water',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Long term stays allowed',
#    'Luggage dropoff allowed',
#    'Other',
#    'Oven',
#    'Paid parking off premises',
#    'Refrigerator',
#    'Shampoo',
#    'Smoke detector',
#    'TV',
#    'Wifi',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50']},
#  {'_id': '10269320',
#   'amenities': ['Bed linens',
#    'Cable TV',
#    'Elevator',
#    'Essentials',
#    'Extra pillows and blankets',
#    'Fire extinguisher',
#    'First aid kit',
#    'Hair dryer',
#    'Hangers',
#    'Hot water',
#    'Internet',
#    'Laptop friendly workspace',
#    'Lockbox',
#    'Self check-in',
#    'Shampoo',
#    'TV',
#    'Wifi',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50']},
#  {'_id': '102995',
#   'amenities': ['24-hour check-in',
#    'Air conditioning',
#    'Buzzer/wireless intercom',
#    'Cable TV',
#    'Carbon monoxide detector',
#    'Dryer',
#    'Essentials',
#    'Fire extinguisher',
#    'First aid kit',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Private entrance',
#    'Smoke detector',
#    'TV',
#    'Washer',
#    'Wifi',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50']},
#  {'_id': '10280433',
#   'amenities': ['24-hour check-in',
#    'Bed linens',
#    'Breakfast',
#    'Carbon monoxide detector',
#    'Coffee maker',
#    'Cooking basics',
#    'Dishes and silverware',
#    'Essentials',
#    'Extra pillows and blankets',
#    'Fire extinguisher',
#    'First aid kit',
#    'Free parking on premises',
#    'Garden or backyard',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Host greets you',
#    'Hot water',
#    'Indoor fireplace',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Microwave',
#    'Oven',
#    'Patio or balcony',
#    'Refrigerator',
#    'Safety card',
#    'Shampoo',
#    'Smoke detector',
#    'Stove',
#    'Wifi',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50']},
#  {'_id': '10306879',
#   'amenities': ['Air conditioning',
#    'Buzzer/wireless intercom',
#    'Doorman',
#    'Dryer',
#    'Elevator',
#    'Family/kid friendly',
#    'Free parking on premises',
#    'Gym',
#    'Hangers',
#    'Hot tub',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Pets allowed',
#    'Pool',
#    'TV',
#    'Washer',
#    'Wifi']},
#  {'_id': '10423504',
#   'amenities': ['BBQ grill',
#    'Bathtub',
#    'Bed linens',
#    'Coffee maker',
#    'Cooking basics',
#    'Dishes and silverware',
#    'Dishwasher',
#    'Dryer',
#    'Essentials',
#    'Ethernet connection',
#    'Extra pillows and blankets',
#    'Family/kid friendly',
#    'Fireplace guards',
#    'Free parking on premises',
#    'Garden or backyard',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'High chair',
#    'Hot water',
#    'Indoor fireplace',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Lockbox',
#    'Long term stays allowed',
#    'Luggage dropoff allowed',
#    'Microwave',
#    'Oven',
#    'Pack ’n Play/travel crib',
#    'Paid parking off premises',
#    'Patio or balcony',
#    'Pets allowed',
#    'Private entrance',
#    'Refrigerator',
#    'Self check-in',
#    'Shampoo',
#    'Single level home',
#    'Smoke detector',
#    'Smoking allowed',
#    'Stove',
#    'TV',
#    'Washer',
#    'Wifi']},
#  {'_id': '10359729',
#   'amenities': ['24-hour check-in',
#    'Doorman',
#    'Essentials',
#    'First aid kit',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Lock on bedroom door',
#    'Shampoo',
#    'Smoking allowed',
#    'Washer',
#    'Wifi']},
#  {'_id': '10317142',
#   'amenities': ['24-hour check-in',
#    'Beachfront',
#    'Cable TV',
#    'Dryer',
#    'Essentials',
#    'Family/kid friendly',
#    'Free parking on premises',
#    'Hair dryer',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Smoke detector',
#    'Suitable for events',
#    'TV',
#    'Washer',
#    'Wheelchair accessible',
#    'Wifi']},
#  {'_id': '10578580',
#   'amenities': ['Cable TV',
#    'Essentials',
#    'Fire extinguisher',
#    'First aid kit',
#    'Free parking on premises',
#    'Free street parking',
#    'Hair dryer',
#    'Hangers',
#    'Hot water',
#    'Internet',
#    'Iron',
#    'Keypad',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Long term stays allowed',
#    'Luggage dropoff allowed',
#    'Pets live on this property',
#    'Self check-in',
#    'Shampoo',
#    'Smoke detector',
#    'TV',
#    'Wifi',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50']},
#  {'_id': '10664888',
#   'amenities': ['Accessible-height bed',
#    'Accessible-height toilet',
#    'Bed linens',
#    'Buzzer/wireless intercom',
#    'Cable TV',
#    'Coffee maker',
#    'Cooking basics',
#    'Dishes and silverware',
#    'Elevator',
#    'Essentials',
#    'Extra pillows and blankets',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'First aid kit',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'High chair',
#    'Host greets you',
#    'Hot water',
#    'Iron',
#    'Kitchen',
#    'Long term stays allowed',
#    'Microwave',
#    'Pack ’n Play/travel crib',
#    'Paid parking off premises',
#    'Paid parking on premises',
#    'Refrigerator',
#    'Shampoo',
#    'Step-free access',
#    'Step-free access',
#    'Step-free access',
#    'Stove',
#    'TV',
#    'Wide clearance to bed',
#    'Wide doorway',
#    'Wide doorway',
#    'Wide doorway',
#    'Wifi']},
#  {'_id': '10542174',
#   'amenities': ['24-hour check-in',
#    'Air conditioning',
#    'Buzzer/wireless intercom',
#    'Carbon monoxide detector',
#    'Doorman',
#    'Dryer',
#    'Elevator',
#    'Essentials',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'First aid kit',
#    'Gym',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Safety card',
#    'Shampoo',
#    'Smoke detector',
#    'TV',
#    'Washer',
#    'Wheelchair accessible',
#    'Wifi']},
#  {'_id': '10570041',
#   'amenities': ['Air conditioning',
#    'Babysitter recommendations',
#    'Beach essentials',
#    'Bed linens',
#    'Building staff',
#    'Cable TV',
#    'Carbon monoxide detector',
#    'Changing table',
#    'Children’s books and toys',
#    'Children’s dinnerware',
#    'Coffee maker',
#    'Cooking basics',
#    'Dishes and silverware',
#    'Elevator',
#    'Essentials',
#    'Ethernet connection',
#    'Extra pillows and blankets',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'First aid kit',
#    'Free parking on premises',
#    'Free street parking',
#    'Garden or backyard',
#    'Gym',
#    'Hair dryer',
#    'Hangers',
#    'Hot water',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Lock on bedroom door',
#    'Long term stays allowed',
#    'Luggage dropoff allowed',
#    'Microwave',
#    'Oven',
#    'Patio or balcony',
#    'Pets allowed',
#    'Pool',
#    'Private living room',
#    'Refrigerator',
#    'Room-darkening shades',
#    'Self check-in',
#    'Shampoo',
#    'Smoke detector',
#    'Stair gates',
#    'Stove',
#    'TV',
#    'Washer',
#    'Wifi',
#    'Window guards']},
#  {'_id': '1038163',
#   'amenities': ['Air conditioning',
#    'Cable TV',
#    'Doorman',
#    'Elevator',
#    'Essentials',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'Heating',
#    'Internet',
#    'Kitchen',
#    'Shampoo',
#    'Wifi']},
#  {'_id': '10448594',
#   'amenities': ['Buzzer/wireless intercom',
#    'Cable TV',
#    'Doorman',
#    'Elevator',
#    'Essentials',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'First aid kit',
#    'Free parking on premises',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Hot tub',
#    'Indoor fireplace',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Pool',
#    'Safety card',
#    'Shampoo',
#    'Smoke detector',
#    'TV',
#    'Washer',
#    'Wheelchair accessible',
#    'Wifi']},
#  {'_id': '10487917',
#   'amenities': ['24-hour check-in',
#    'Bed linens',
#    'Cable TV',
#    'Cooking basics',
#    'Dishes and silverware',
#    'Essentials',
#    'Extra pillows and blankets',
#    'Fire extinguisher',
#    'First aid kit',
#    'Free street parking',
#    'Hair dryer',
#    'Handheld shower head',
#    'Hangers',
#    'Heating',
#    'Host greets you',
#    'Hot water',
#    'Internet',
#    'Kitchen',
#    'Long term stays allowed',
#    'Microwave',
#    'Refrigerator',
#    'Room-darkening shades',
#    'Safety card',
#    'Shampoo',
#    'Single level home',
#    'Stove',
#    'TV',
#    'Wifi',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50']},
#  {'_id': '10488837',
#   'amenities': ['24-hour check-in',
#    'Essentials',
#    'Family/kid friendly',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Shampoo',
#    'Smoking allowed',
#    'Washer',
#    'Wifi']},
#  {'_id': '1069531',
#   'amenities': ['Cable TV',
#    'Dryer',
#    'Essentials',
#    'First aid kit',
#    'Free parking on premises',
#    'Hair dryer',
#    'Hangers',
#    'Host greets you',
#    'Hot tub',
#    'Hot water',
#    'Iron',
#    'Kitchen',
#    'Lock on bedroom door',
#    'Luggage dropoff allowed',
#    'Pack ’n Play/travel crib',
#    'Pool',
#    'Private entrance',
#    'Shampoo',
#    'Smoke detector',
#    'Suitable for events',
#    'TV',
#    'Washer',
#    'Wifi',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50']},
#  {'_id': '10545725',
#   'amenities': ['Buzzer/wireless intercom',
#    'Essentials',
#    'Family/kid friendly',
#    'Internet',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Pets allowed',
#    'TV',
#    'Washer',
#    'Wifi']},
#  {'_id': '10332161',
#   'amenities': ['Air conditioning',
#    'Dryer',
#    'Essentials',
#    'First aid kit',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Iron',
#    'Kitchen',
#    'Lock on bedroom door',
#    'Smoke detector',
#    'Washer',
#    'Wifi',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50']},
#  {'_id': '10612199',
#   'amenities': ['Air conditioning',
#    'Bed linens',
#    'Buzzer/wireless intercom',
#    'Elevator',
#    'Essentials',
#    'Extra pillows and blankets',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Washer',
#    'Wifi']},
#  {'_id': '10471178',
#   'amenities': ['Buzzer/wireless intercom',
#    'Doorman',
#    'Dryer',
#    'Elevator',
#    'Essentials',
#    'Hair dryer',
#    'Hangers',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Lock on bedroom door',
#    'Wifi']},
#  {'_id': '10519173',
#   'amenities': ['Air conditioning',
#    'Buzzer/wireless intercom',
#    'Cable TV',
#    'Coffee maker',
#    'Dishes and silverware',
#    'Doorman',
#    'Elevator',
#    'Family/kid friendly',
#    'First aid kit',
#    'Free parking on premises',
#    'Hair dryer',
#    'Hangers',
#    'Hot water',
#    'Iron',
#    'Kitchen',
#    'Long term stays allowed',
#    'Microwave',
#    'Other',
#    'Pool',
#    'Refrigerator',
#    'Stove',
#    'TV',
#    'Washer',
#    'Well-lit path to entrance',
#    'Wheelchair accessible',
#    'Wifi']},
#  {'_id': '10677883',
#   'amenities': ['Air conditioning',
#    'Elevator',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'Hangers',
#    'Internet',
#    'Kitchen',
#    'Smoking allowed',
#    'Washer']},
#  {'_id': '10373872',
#   'amenities': ['24-hour check-in',
#    'Air conditioning',
#    'Building staff',
#    'Buzzer/wireless intercom',
#    'Cable TV',
#    'Doorman',
#    'Dryer',
#    'Elevator',
#    'Essentials',
#    'Family/kid friendly',
#    'Free parking on premises',
#    'Gym',
#    'Hair dryer',
#    'Hangers',
#    'Hot water',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Long term stays allowed',
#    'Luggage dropoff allowed',
#    'Pool',
#    'Self check-in',
#    'TV',
#    'Washer',
#    'Wifi']},
#  {'_id': '10548991',
#   'amenities': ['24-hour check-in',
#    'Air conditioning',
#    'Cable TV',
#    'Dryer',
#    'Essentials',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'Free parking on premises',
#    'Free street parking',
#    'Hair dryer',
#    'Hangers',
#    'Hot water',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Other',
#    'Pack ’n Play/travel crib',
#    'Private entrance',
#    'Shampoo',
#    'Smoke detector',
#    'TV',
#    'Washer',
#    'Wifi']},
#  {'_id': '10596036',
#   'amenities': ['Air conditioning',
#    'Buzzer/wireless intercom',
#    'Cable TV',
#    'Doorman',
#    'Elevator',
#    'Essentials',
#    'Family/kid friendly',
#    'Hangers',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'TV',
#    'Washer',
#    'Wifi']},
#  {'_id': '1067052',
#   'amenities': ['Bed linens',
#    'Breakfast',
#    'Cat(s)',
#    'Coffee maker',
#    'Dishes and silverware',
#    'Dog(s)',
#    'Essentials',
#    'Free parking on premises',
#    'Hair dryer',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Microwave',
#    'Other pet(s)',
#    'Pets live on this property',
#    'Private entrance',
#    'Refrigerator',
#    'Shampoo',
#    'Wifi']},
#  {'_id': '10431455',
#   'amenities': ['24-hour check-in',
#    'Air conditioning',
#    'Buzzer/wireless intercom',
#    'Cable TV',
#    'Doorman',
#    'Elevator',
#    'Essentials',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'Internet',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Pets allowed',
#    'Shampoo',
#    'Smoking allowed',
#    'TV',
#    'Washer',
#    'Wifi',
#    'translation missing: en.hosting_amenity_50']},
#  {'_id': '10459480',
#   'amenities': ['Air conditioning',
#    'Buzzer/wireless intercom',
#    'Essentials',
#    'Family/kid friendly',
#    'First aid kit',
#    'Free parking on premises',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Indoor fireplace',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Pool',
#    'Shampoo',
#    'Smoke detector',
#    'TV',
#    'Washer',
#    'Wifi']},
#  {'_id': '10486984',
#   'amenities': ['24-hour check-in',
#    'Air conditioning',
#    'Bed linens',
#    'Cable TV',
#    'Crib',
#    'Essentials',
#    'Extra pillows and blankets',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'First aid kit',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Host greets you',
#    'Hot water',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Long term stays allowed',
#    'Paid parking off premises',
#    'Shampoo',
#    'Step-free access',
#    'Suitable for events',
#    'TV',
#    'Washer',
#    'Wifi']},
#  {'_id': '10648267',
#   'amenities': ['Buzzer/wireless intercom',
#    'Essentials',
#    'Family/kid friendly',
#    'Hangers',
#    'Internet',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'TV',
#    'Wifi']},
#  {'_id': '10675315',
#   'amenities': ['Cat(s)',
#    'Dryer',
#    'Essentials',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Pets live on this property',
#    'Smoke detector',
#    'TV',
#    'Washer',
#    'Wifi']},
#  {'_id': '10354347',
#   'amenities': ['24-hour check-in',
#    'Cable TV',
#    'Doorman',
#    'Dryer',
#    'Elevator',
#    'Essentials',
#    'Family/kid friendly',
#    'Free parking on premises',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Host greets you',
#    'Hot water',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Private living room',
#    'Smoking allowed',
#    'Suitable for events',
#    'TV',
#    'Washer',
#    'Wifi']},
#  {'_id': '10383490',
#   'amenities': ['24-hour check-in',
#    'Buzzer/wireless intercom',
#    'Cable TV',
#    'Elevator',
#    'Essentials',
#    'Family/kid friendly',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Lock on bedroom door',
#    'Smoking allowed',
#    'Washer',
#    'Wifi',
#    'translation missing: en.hosting_amenity_50']},
#  {'_id': '10628126',
#   'amenities': ['Bed linens',
#    'Buzzer/wireless intercom',
#    'Coffee maker',
#    'Cooking basics',
#    'Dishes and silverware',
#    'Essentials',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'First aid kit',
#    'Hair dryer',
#    'Hangers',
#    'Host greets you',
#    'Hot water',
#    'Internet',
#    'Kitchen',
#    'Long term stays allowed',
#    'Microwave',
#    'Oven',
#    'Paid parking off premises',
#    'Refrigerator',
#    'Safety card',
#    'Shampoo',
#    'Stove',
#    'Washer',
#    'Wifi']},
#  {'_id': '10639317',
#   'amenities': ['24-hour check-in',
#    'Buzzer/wireless intercom',
#    'Essentials',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Internet',
#    'Kitchen',
#    'Shampoo',
#    'Smoking allowed',
#    'Washer',
#    'Wifi']},
#  {'_id': '10552362',
#   'amenities': ['Buzzer/wireless intercom',
#    'Essentials',
#    'Hangers',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Shampoo',
#    'Smoke detector',
#    'TV',
#    'Wifi']},
#  {'_id': '1036027',
#   'amenities': ['Cable TV',
#    'Elevator',
#    'Essentials',
#    'Family/kid friendly',
#    'Heating',
#    'Internet',
#    'Kitchen',
#    'Shampoo',
#    'TV',
#    'Washer',
#    'Wifi']},
#  {'_id': '10343118',
#   'amenities': ['24-hour check-in',
#    'Air conditioning',
#    'Cable TV',
#    'Carbon monoxide detector',
#    'Elevator',
#    'Essentials',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Hot water',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Lockbox',
#    'Paid parking off premises',
#    'Self check-in',
#    'Shampoo',
#    'Smoke detector',
#    'TV',
#    'Wheelchair accessible',
#    'Wifi']},
#  {'_id': '10324377',
#   'amenities': ['Buzzer/wireless intercom',
#    'Cable TV',
#    'Free parking on premises',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Lock on bedroom door',
#    'Pool',
#    'Smoking allowed',
#    'Wifi']},
#  {'_id': '1042446',
#   'amenities': ['24-hour check-in',
#    'Air conditioning',
#    'Cable TV',
#    'Dryer',
#    'Elevator',
#    'Essentials',
#    'Family/kid friendly',
#    'Free parking on premises',
#    'Hair dryer',
#    'Hangers',
#    'Hot water',
#    'Internet',
#    'Iron',
#    'Keypad',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Pool',
#    'Self check-in',
#    'Smoke detector',
#    'TV',
#    'Washer',
#    'Wifi']},
#  {'_id': '10624493',
#   'amenities': ['Air conditioning',
#    'Elevator',
#    'Essentials',
#    'Family/kid friendly',
#    'Hangers',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Pool',
#    'Smoking allowed',
#    'Washer',
#    'Wheelchair accessible']},
#  {'_id': '10415637',
#   'amenities': ['Air conditioning',
#    'Essentials',
#    'Family/kid friendly',
#    'Free parking on premises',
#    'Hair dryer',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Shampoo',
#    'TV',
#    'Wifi']},
#  {'_id': '10527212',
#   'amenities': ['24-hour check-in',
#    'Air conditioning',
#    'Essentials',
#    'Hair dryer',
#    'Heating',
#    'Hot water',
#    'Kitchen',
#    'Shampoo',
#    'TV']},
#  {'_id': '10573225',
#   'amenities': ['Air conditioning',
#    'Cable TV',
#    'Carbon monoxide detector',
#    'Coffee maker',
#    'Cooking basics',
#    'Dishes and silverware',
#    'Dishwasher',
#    'Essentials',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'First aid kit',
#    'Free street parking',
#    'Garden or backyard',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Hot water',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Lockbox',
#    'Long term stays allowed',
#    'Luggage dropoff allowed',
#    'Microwave',
#    'Oven',
#    'Paid parking off premises',
#    'Refrigerator',
#    'Safety card',
#    'Self check-in',
#    'Shampoo',
#    'Single level home',
#    'Smoke detector',
#    'Stove',
#    'TV',
#    'Wifi']},
#  {'_id': '1068505',
#   'amenities': ['Cable TV',
#    'Carbon monoxide detector',
#    'Essentials',
#    'Family/kid friendly',
#    'Free street parking',
#    'Hair dryer',
#    'Heating',
#    'Host greets you',
#    'Hot water',
#    'Internet',
#    'Kitchen',
#    'Paid parking off premises',
#    'Shampoo',
#    'Smoke detector',
#    'TV',
#    'Wifi']},
#  {'_id': '10381879',
#   'amenities': ['Air conditioning',
#    'Breakfast',
#    'Cable TV',
#    'Essentials',
#    'Family/kid friendly',
#    'Hangers',
#    'TV',
#    'Wifi']},
#  {'_id': '1063491',
#   'amenities': ['Air conditioning',
#    'Bed linens',
#    'Cable TV',
#    'Carbon monoxide detector',
#    'Coffee maker',
#    'Cooking basics',
#    'Dishes and silverware',
#    'Dishwasher',
#    'Dryer',
#    'Elevator',
#    'Essentials',
#    'Ethernet connection',
#    'Extra pillows and blankets',
#    'Hair dryer',
#    'Hangers',
#    'Hot water',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Lockbox',
#    'Long term stays allowed',
#    'Luggage dropoff allowed',
#    'Microwave',
#    'Private entrance',
#    'Private living room',
#    'Refrigerator',
#    'Room-darkening shades',
#    'Self check-in',
#    'Shampoo',
#    'Smoke detector',
#    'Stove',
#    'TV',
#    'Washer',
#    'Wifi']},
#  {'_id': '10458796',
#   'amenities': ['Air conditioning',
#    'Bed linens',
#    'Cable TV',
#    'Carbon monoxide detector',
#    'Cooking basics',
#    'Dishes and silverware',
#    'Elevator',
#    'Essentials',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'First aid kit',
#    'Flat path to front door',
#    'Gym',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Host greets you',
#    'Hot water',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Lock on bedroom door',
#    'Long term stays allowed',
#    'Luggage dropoff allowed',
#    'Microwave',
#    'Oven',
#    'Patio or balcony',
#    'Pool',
#    'Refrigerator',
#    'Single level home',
#    'Smoke detector',
#    'Step-free access',
#    'Step-free access',
#    'Step-free access',
#    'Step-free access',
#    'Stove',
#    'TV',
#    'Well-lit path to entrance',
#    'Wide doorway',
#    'Wide entryway',
#    'Wide hallway clearance',
#    'Wifi']},
#  {'_id': '10449328',
#   'amenities': ['Air conditioning',
#    'Breakfast',
#    'Essentials',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'First aid kit',
#    'Free parking on premises',
#    'Hot tub',
#    'Internet',
#    'Kitchen',
#    'Pets allowed',
#    'Pets live on this property',
#    'Pool',
#    'Shampoo',
#    'Smoking allowed',
#    'Suitable for events',
#    'TV',
#    'Washer',
#    'Wifi']},
#  {'_id': '10416859',
#   'amenities': ['Accessible-height bed',
#    'Air conditioning',
#    'BBQ grill',
#    'Bed linens',
#    'Cable TV',
#    'Carbon monoxide detector',
#    'Children’s books and toys',
#    'Children’s dinnerware',
#    'Coffee maker',
#    'Cooking basics',
#    'Dishes and silverware',
#    'Dishwasher',
#    'Essentials',
#    'Extra pillows and blankets',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'First aid kit',
#    'Free street parking',
#    'Garden or backyard',
#    'Gym',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'High chair',
#    'Hot water',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Lock on bedroom door',
#    'Lockbox',
#    'Luggage dropoff allowed',
#    'Microwave',
#    'Outlet covers',
#    'Patio or balcony',
#    'Private entrance',
#    'Private living room',
#    'Refrigerator',
#    'Self check-in',
#    'Shampoo',
#    'Smoke detector',
#    'Step-free access',
#    'Step-free access',
#    'Step-free access',
#    'Stove',
#    'TV',
#    'Washer',
#    'Well-lit path to entrance',
#    'Wide doorway',
#    'Wide hallway clearance',
#    'Wifi']},
#  {'_id': '10392282',
#   'amenities': ['24-hour check-in',
#    'Cable TV',
#    'Dog(s)',
#    'Dryer',
#    'Essentials',
#    'Family/kid friendly',
#    'First aid kit',
#    'Free parking on premises',
#    'Hair dryer',
#    'Hangers',
#    'Hot water',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Pets live on this property',
#    'Safety card',
#    'Shampoo',
#    'Smoke detector',
#    'TV',
#    'Washer',
#    'Wifi']},
#  {'_id': '10581101',
#   'amenities': ['Air conditioning',
#    'Buzzer/wireless intercom',
#    'Dryer',
#    'Essentials',
#    'Family/kid friendly',
#    'Hair dryer',
#    'Hangers',
#    'Host greets you',
#    'Hot water',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Paid parking off premises',
#    'Shampoo',
#    'Smoking allowed',
#    'TV',
#    'Washer',
#    'Wifi']},
#  {'_id': '10635276',
#   'amenities': ['Air conditioning',
#    'Bathtub',
#    'Beachfront',
#    'Bed linens',
#    'Cable TV',
#    'Coffee maker',
#    'Cooking basics',
#    'Disabled parking spot',
#    'Dishes and silverware',
#    'Dryer',
#    'Elevator',
#    'Essentials',
#    'Ethernet connection',
#    'Extra pillows and blankets',
#    'Family/kid friendly',
#    'Free parking on premises',
#    'Free street parking',
#    'Gym',
#    'Handheld shower head',
#    'Hangers',
#    'Host greets you',
#    'Hot water',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Lock on bedroom door',
#    'Long term stays allowed',
#    'Microwave',
#    'Oven',
#    'Patio or balcony',
#    'Pets allowed',
#    'Private living room',
#    'Refrigerator',
#    'Shampoo',
#    'Smoking allowed',
#    'Step-free access',
#    'Step-free access',
#    'Step-free access',
#    'Stove',
#    'TV',
#    'Washer',
#    'Well-lit path to entrance',
#    'Wifi',
#    'Window guards']},
#  {'_id': '10659534',
#   'amenities': ['Air conditioning',
# ...
#    'Microwave',
#    'Oven',
#    'Pool',
#    'Refrigerator',
#    'Roll-in shower',
#    'Smoking allowed',
#    'Step-free access',
#    'Step-free access',
#    'Step-free access',
#    'Step-free access',
#    'Stove',
#    'Washer',
#    'Well-lit path to entrance',
#    'Wide clearance to bed',
#    'Wide clearance to shower',
#    'Wide doorway',
#    'Wide doorway',
#    'Wide doorway',
#    'Wide entryway',
#    'Wide hallway clearance',
#    'Wifi',
#    'toilet']},
#  {'_id': '15241263',
#   'amenities': ['Air conditioning',
#    'Beach essentials',
#    'Bed linens',
#    'Cable TV',
#    'Coffee maker',
#    'Cooking basics',
#    'Dishes and silverware',
#    'Dishwasher',
#    'Dryer',
#    'Essentials',
#    'Fire extinguisher',
#    'First aid kit',
#    'Free street parking',
#    'Garden or backyard',
#    'Hair dryer',
#    'Hangers',
#    'Host greets you',
#    'Hot water',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Lock on bedroom door',
#    'Luggage dropoff allowed',
#    'Microwave',
#    'Oven',
#    'Patio or balcony',
#    'Refrigerator',
#    'Shampoo',
#    'Smoke detector',
#    'Stove',
#    'TV',
#    'Washer',
#    'Well-lit path to entrance',
#    'Wifi',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50']},
#  {'_id': '152259',
#   'amenities': ['Air conditioning',
#    'Carbon monoxide detector',
#    'Cat(s)',
#    'Essentials',
#    'Free street parking',
#    'Hair dryer',
#    'Heating',
#    'Hot water',
#    'Internet',
#    'Kitchen',
#    'Other',
#    'Paid parking off premises',
#    'Pets live on this property',
#    'Shampoo',
#    'Smoke detector',
#    'TV',
#    'Wifi']},
#  {'_id': '15239628',
#   'amenities': ['Essentials',
#    'Hangers',
#    'Heating',
#    'Iron',
#    'Kitchen',
#    'Shampoo',
#    'TV',
#    'Wifi',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50']},
#  {'_id': '15366738',
#   'amenities': ['Essentials',
#    'Hangers',
#    'Heating',
#    'Kitchen',
#    'Smoking allowed',
#    'Washer',
#    'Wifi',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50']},
#  {'_id': '15284591',
#   'amenities': ['Air conditioning',
#    'Essentials',
#    'Family/kid friendly',
#    'Hair dryer',
#    'Heating',
#    'Host greets you',
#    'Hot water',
#    'Internet',
#    'Lock on bedroom door',
#    'Paid parking off premises',
#    'Shampoo',
#    'Wifi']},
#  {'_id': '15245956',
#   'amenities': ['Carbon monoxide detector',
#    'Dryer',
#    'Essentials',
#    'Family/kid friendly',
#    'Hair dryer',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Shampoo',
#    'Smoke detector',
#    'TV',
#    'Washer',
#    'Wifi']},
#  {'_id': '15309509',
#   'amenities': ['24-hour check-in',
#    'Air conditioning',
#    'Carbon monoxide detector',
#    'Children’s books and toys',
#    'Crib',
#    'Dryer',
#    'Elevator',
#    'Essentials',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'First aid kit',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'High chair',
#    'Host greets you',
#    'Hot water',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Long term stays allowed',
#    'Luggage dropoff allowed',
#    'Pack ’n Play/travel crib',
#    'Paid parking on premises',
#    'Pets allowed',
#    'Safety card',
#    'Shampoo',
#    'Smoke detector',
#    'TV',
#    'Washer',
#    'Wheelchair accessible',
#    'Wifi']},
#  {'_id': '15286461',
#   'amenities': ['Bathtub',
#    'Cable TV',
#    'Crib',
#    'Dryer',
#    'Essentials',
#    'Free parking on premises',
#    'Gym',
#    'Hair dryer',
#    'Hangers',
#    'High chair',
#    'Hot tub',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Outlet covers',
#    'Pool',
#    'Private entrance',
#    'Private living room',
#    'Shampoo',
#    'Smoke detector',
#    'TV',
#    'Washer',
#    'Wifi']},
#  {'_id': '15248025',
#   'amenities': ['Air conditioning',
#    'Elevator',
#    'Essentials',
#    'Family/kid friendly',
#    'Hangers',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Lock on bedroom door',
#    'TV',
#    'Washer',
#    'Wifi']},
#  {'_id': '15312988',
#   'amenities': ['Cooking basics',
#    'Dishes and silverware',
#    'Essentials',
#    'Free street parking',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Hot water',
#    'Iron',
#    'Kitchen',
#    'Lockbox',
#    'Luggage dropoff allowed',
#    'Microwave',
#    'Oven',
#    'Refrigerator',
#    'Room-darkening shades',
#    'Self check-in',
#    'Shampoo',
#    'Smoke detector',
#    'Step-free access',
#    'Step-free access',
#    'Step-free access',
#    'Stove',
#    'TV',
#    'Washer',
#    'Wide clearance to bed',
#    'Wifi',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50']},
#  {'_id': '15326391',
#   'amenities': ['24-hour check-in',
#    'Air conditioning',
#    'Dryer',
#    'Essentials',
#    'Family/kid friendly',
#    'Free parking on premises',
#    'Heating',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'TV',
#    'Washer',
#    'Wifi']},
#  {'_id': '15353532',
#   'amenities': ['Essentials',
#    'Smoking allowed',
#    'Wifi',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50']},
#  {'_id': '1530241',
#   'amenities': ['24-hour check-in',
#    'Air conditioning',
#    'Buzzer/wireless intercom',
#    'Dishes and silverware',
#    'Doorman',
#    'Elevator',
#    'Hangers',
#    'Host greets you',
#    'Hot water',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Long term stays allowed',
#    'Luggage dropoff allowed',
#    'Microwave',
#    'Smoking allowed',
#    'Stove',
#    'TV',
#    'Wifi']},
#  {'_id': '15285878',
#   'amenities': ['Cable TV',
#    'Dryer',
#    'Essentials',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'First aid kit',
#    'Free parking on premises',
#    'Hangers',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Pack ’n Play/travel crib',
#    'Pool',
#    'Private entrance',
#    'Shampoo',
#    'Smoke detector',
#    'TV',
#    'Washer',
#    'Wifi']},
#  {'_id': '15314458',
#   'amenities': ['Air conditioning',
#    'Cable TV',
#    'Dryer',
#    'Essentials',
#    'Family/kid friendly',
#    'Hair dryer',
#    'Hangers',
#    'Hot water',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Lockbox',
#    'Self check-in',
#    'Shampoo',
#    'TV',
#    'Washer',
#    'Wifi']},
#  {'_id': '15320378',
#   'amenities': ['Elevator',
#    'Essentials',
#    'Fire extinguisher',
#    'First aid kit',
#    'Hair dryer',
#    'Hangers',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Shampoo',
#    'Smoking allowed',
#    'Suitable for events',
#    'TV',
#    'Wifi',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50']},
#  {'_id': '15182133',
#   'amenities': ['Air conditioning',
#    'Building staff',
#    'Dryer',
#    'Elevator',
#    'Essentials',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'Free street parking',
#    'Gym',
#    'Hair dryer',
#    'Hangers',
#    'Hot water',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Lock on bedroom door',
#    'Luggage dropoff allowed',
#    'Paid parking on premises',
#    'Pool',
#    'Self check-in',
#    'Shampoo',
#    'Smoke detector',
#    'Suitable for events',
#    'TV',
#    'Washer',
#    'Wifi']},
#  {'_id': '15208698',
#   'amenities': ['Air conditioning',
#    'Bathtub',
#    'Cable TV',
#    'Carbon monoxide detector',
#    'Dryer',
#    'Essentials',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'First aid kit',
#    'Free parking on premises',
#    'Gym',
#    'Hair dryer',
#    'Hangers',
#    'Hot tub',
#    'Hot water',
#    'Internet',
#    'Iron',
#    'Keypad',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Long term stays allowed',
#    'Pack ’n Play/travel crib',
#    'Pool',
#    'Private entrance',
#    'Room-darkening shades',
#    'Self check-in',
#    'Shampoo',
#    'Smoke detector',
#    'TV',
#    'Washer',
#    'Wifi',
#    'translation missing: en.hosting_amenity_50']},
#  {'_id': '15266254',
#   'amenities': ['Air conditioning',
#    'Building staff',
#    'Dryer',
#    'Elevator',
#    'Essentials',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'Free parking on premises',
#    'Gym',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Hot water',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Luggage dropoff allowed',
#    'Pool',
#    'Self check-in',
#    'Shampoo',
#    'Smoke detector',
#    'TV',
#    'Washer',
#    'Wifi']},
#  {'_id': '152645',
#   'amenities': ['BBQ grill',
#    'Bed linens',
#    'Cable TV',
#    'Coffee maker',
#    'Dishes and silverware',
#    'Essentials',
#    'Extra pillows and blankets',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'Free parking on premises',
#    'Hair dryer',
#    'Hangers',
#    'Hot tub',
#    'Hot water',
#    'Internet',
#    'Iron',
#    'Lockbox',
#    'Microwave',
#    'Patio or balcony',
#    'Pool',
#    'Private entrance',
#    'Refrigerator',
#    'Self check-in',
#    'Shampoo',
#    'Smoke detector',
#    'TV',
#    'Wifi']},
#  {'_id': '15207202',
#   'amenities': ['Air conditioning',
#    'Bathtub',
#    'Buzzer/wireless intercom',
#    'Dryer',
#    'Essentials',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Hot water',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Lock on bedroom door',
#    'Lockbox',
#    'Pets allowed',
#    'Self check-in',
#    'Shampoo',
#    'Smoke detector',
#    'Washer',
#    'Wifi']},
#  {'_id': '15294219',
#   'amenities': ['24-hour check-in',
#    'Air conditioning',
#    'Baby bath',
#    'Babysitter recommendations',
#    'Buzzer/wireless intercom',
#    'Cable TV',
#    'Carbon monoxide detector',
#    'Children’s books and toys',
#    'Children’s dinnerware',
#    'Doorman',
#    'Elevator',
#    'Essentials',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'First aid kit',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'High chair',
#    'Host greets you',
#    'Hot water',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Long term stays allowed',
#    'Outlet covers',
#    'Pack ’n Play/travel crib',
#    'Paid parking off premises',
#    'Room-darkening shades',
#    'Shampoo',
#    'Smoke detector',
#    'TV',
#    'Washer',
#    'Wifi',
#    'Window guards']},
#  {'_id': '15307723',
#   'amenities': ['24-hour check-in',
#    'Breakfast',
#    'Carbon monoxide detector',
#    'Dryer',
#    'Elevator',
#    'Essentials',
#    'Family/kid friendly',
#    'Gym',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Pool',
#    'Shampoo',
#    'Smoke detector',
#    'Suitable for events',
#    'Washer',
#    'Wheelchair accessible',
#    'Wifi']},
#  {'_id': '15360364',
#   'amenities': ['24-hour check-in',
#    'Air conditioning',
#    'Carbon monoxide detector',
#    'Essentials',
#    'Family/kid friendly',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Pets allowed',
#    'Shampoo',
#    'Smoke detector',
#    'TV',
#    'Wifi']},
#  {'_id': '15362525',
#   'amenities': ['Air conditioning',
#    'Carbon monoxide detector',
#    'Coffee maker',
#    'Cooking basics',
#    'Dishes and silverware',
#    'Essentials',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'First aid kit',
#    'Free street parking',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Internet',
#    'Iron',
#    'Keypad',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Microwave',
#    'Paid parking off premises',
#    'Refrigerator',
#    'Self check-in',
#    'Shampoo',
#    'Smoke detector',
#    'TV',
#    'Wifi']},
#  {'_id': '15194147',
#   'amenities': ['Air conditioning',
#    'Dryer',
#    'Essentials',
#    'Family/kid friendly',
#    'Hair dryer',
#    'Hangers',
#    'Hot water',
#    'Kitchen',
#    'Lockbox',
#    'Long term stays allowed',
#    'Luggage dropoff allowed',
#    'Self check-in',
#    'Shampoo',
#    'Smoke detector',
#    'TV',
#    'Washer']},
#  {'_id': '15244301',
#   'amenities': ['BBQ grill',
#    'Babysitter recommendations',
#    'Beach essentials',
#    'Breakfast',
#    'Buzzer/wireless intercom',
#    'Cleaning before checkout',
#    'Coffee maker',
#    'Cooking basics',
#    'Dishes and silverware',
#    'Dishwasher',
#    'Essentials',
#    'Family/kid friendly',
#    'First aid kit',
#    'Hair dryer',
#    'Hot water',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Luggage dropoff allowed',
#    'Microwave',
#    'Other',
#    'Oven',
#    'Paid parking off premises',
#    'Patio or balcony',
#    'Pets allowed',
#    'Pool',
#    'Refrigerator',
#    'Shampoo',
#    'Smoke detector',
#    'Smoking allowed',
#    'Stove',
#    'Washer',
#    'Well-lit path to entrance',
#    'Wifi']},
#  {'_id': '15257124',
#   'amenities': ['Air conditioning',
#    'Beachfront',
#    'Breakfast',
#    'Cable TV',
#    'Dryer',
#    'Elevator',
#    'Essentials',
#    'Fire extinguisher',
#    'First aid kit',
#    'Free parking on premises',
#    'Free street parking',
#    'Hair dryer',
#    'Hangers',
#    'Hot water',
#    'Iron',
#    'Keypad',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Long term stays allowed',
#    'Other',
#    'Pool',
#    'Private entrance',
#    'Room-darkening shades',
#    'Self check-in',
#    'Shampoo',
#    'Smoke detector',
#    'TV',
#    'Washer',
#    'Waterfront',
#    'Wifi',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50']},
#  {'_id': '152630',
#   'amenities': ['Buzzer/wireless intercom',
#    'Cable TV',
#    'Dryer',
#    'Family/kid friendly',
#    'Free street parking',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Host greets you',
#    'Hot water',
#    'Indoor fireplace',
#    'Iron',
#    'Kitchen',
#    'Laptop friendly workspace',
#    'Long term stays allowed',
#    'Smoke detector',
#    'Washer',
#    'Wifi']},
#  {'_id': '15374146', 'amenities': ['Family/kid friendly', 'Smoking allowed']},
#  {'_id': '15206608',
#   'amenities': ['Dryer',
#    'Essentials',
#    'Family/kid friendly',
#    'First aid kit',
#    'Free street parking',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Hot water',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Private entrance',
#    'Self check-in',
#    'Shampoo',
#    'Smart lock',
#    'Smoke detector',
#    'TV',
#    'Washer',
#    'Wifi']},
#  {'_id': '15225155',
#   'amenities': ['Air conditioning',
#    'Carbon monoxide detector',
#    'Dryer',
#    'Elevator',
#    'Essentials',
#    'Family/kid friendly',
#    'Free parking on premises',
#    'Gym',
#    'Hair dryer',
#    'Heating',
#    'Host greets you',
#    'Hot water',
#    'Iron',
#    'Kitchen',
#    'Pool',
#    'TV',
#    'Washer',
#    'Wifi',
#    'translation missing: en.hosting_amenity_50']},
#  {'_id': '15332652',
#   'amenities': ['Air conditioning',
#    'Essentials',
#    'Family/kid friendly',
#    'Free street parking',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Host greets you',
#    'Hot water',
#    'Internet',
#    'Iron',
#    'Kitchen',
#    'Lock on bedroom door',
#    'Shampoo',
#    'Smoke detector',
#    'TV',
#    'Washer',
#    'Wifi',
#    'translation missing: en.hosting_amenity_50']},
#  {'_id': '15341505',
#   'amenities': ['Accessible-height bed',
#    'Bed linens',
#    'Breakfast',
#    'Building staff',
#    'Dog(s)',
#    'Dryer',
#    'Essentials',
#    'Extra pillows and blankets',
#    'Family/kid friendly',
#    'First aid kit',
#    'Free parking on premises',
#    'Garden or backyard',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Hot water',
#    'Iron',
#    'Laptop friendly workspace',
#    'Lock on bedroom door',
#    'Long term stays allowed',
#    'Luggage dropoff allowed',
#    'Pets live on this property',
#    'Pool',
#    'Private entrance',
#    'Refrigerator',
#    'Self check-in',
#    'Shampoo',
#    'Single level home',
#    'Step-free access',
#    'Step-free access',
#    'Step-free access',
#    'Step-free access',
#    'Washer',
#    'Well-lit path to entrance',
#    'Wide doorway',
#    'Wide entryway',
#    'Wifi']},
#  {'_id': '1534038',
#   'amenities': ['Air conditioning',
#    'Bed linens',
#    'Breakfast',
#    'Dog(s)',
#    'Dryer',
#    'Essentials',
#    'Extra pillows and blankets',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'Free street parking',
#    'Hair dryer',
#    'Hangers',
#    'Heating',
#    'Host greets you',
#    'Hot water',
#    'Internet',
#    'Iron',
#    'Laptop friendly workspace',
#    'Lock on bedroom door',
#    'Long term stays allowed',
#    'Microwave',
#    'Pets live on this property',
#    'Refrigerator',
#    'Safety card',
#    'Shampoo',
#    'Smoke detector',
#    'Washer',
#    'Wifi']},
#  ...]

# %%
df_amenities = pd.DataFrame(amenities)

# %%
df_amenities
# Out:
#            _id                                          amenities
# 0      1003530  [Air conditioning, Buzzer/wireless intercom, D...
# 1     10133554  [Air conditioning, Building staff, Dryer, Esse...
# 2     10059872  [24-hour check-in, Air conditioning, Doorman, ...
# 3     10084023  [Air conditioning, Dishes and silverware, Elev...
# 4     10091713  [Bed linens, Dryer, Elevator, Essentials, Ethe...
# ...        ...                                                ...
# 5550   9985696  [Buzzer/wireless intercom, Cable TV, Dryer, Es...
# 5551   9993190  [Air conditioning, Dryer, Essentials, Family/k...
# 5552   9887054  [24-hour check-in, Air conditioning, Elevator,...
# 5553   9907907  [Dryer, Essentials, Hangers, Internet, Kitchen...
# 5554   9936016  [Air conditioning, Buzzer/wireless intercom, C...
#
# [5555 rows x 2 columns]

# %%
def sort_amenities(x):
    a = x
    a.sort()
    return a

# %%
df_amenities["amenities"] = df_amenities["amenities"].apply(lambda x: sort_amenities(x)) #not used above func

# %%
df_amenities["amenities"]
# Out:
# 0       [Air conditioning, Buzzer/wireless intercom, D...
# 1       [Air conditioning, Building staff, Dryer, Esse...
# 2       [24-hour check-in, Air conditioning, Doorman, ...
# 3       [Air conditioning, Dishes and silverware, Elev...
# 4       [Bed linens, Dryer, Elevator, Essentials, Ethe...
#                               ...
# 5550    [Buzzer/wireless intercom, Cable TV, Dryer, Es...
# 5551    [Air conditioning, Dryer, Essentials, Family/k...
# 5552    [24-hour check-in, Air conditioning, Elevator,...
# 5553    [Dryer, Essentials, Hangers, Internet, Kitchen...
# 5554    [Air conditioning, Buzzer/wireless intercom, C...
# Name: amenities, Length: 5555, dtype: object

# %%
df_amenities.isnull().sum()
# Out:
# _id          0
# amenities    0
# dtype: int64

# %% [markdown]
# # Merging all databases

# %%
df_1
df_host_2
df_address_1
df_available_1 
df_amenities
# Out:
#            _id                                          amenities
# 0      1003530  [Air conditioning, Buzzer/wireless intercom, D...
# 1     10133554  [Air conditioning, Building staff, Dryer, Esse...
# 2     10059872  [24-hour check-in, Air conditioning, Doorman, ...
# 3     10084023  [Air conditioning, Dishes and silverware, Elev...
# 4     10091713  [Bed linens, Dryer, Elevator, Essentials, Ethe...
# ...        ...                                                ...
# 5550   9985696  [Buzzer/wireless intercom, Cable TV, Dryer, Es...
# 5551   9993190  [Air conditioning, Dryer, Essentials, Family/k...
# 5552   9887054  [24-hour check-in, Air conditioning, Elevator,...
# 5553   9907907  [Dryer, Essentials, Hangers, Internet, Kitchen...
# 5554   9936016  [Air conditioning, Buzzer/wireless intercom, C...
#
# [5555 rows x 2 columns]

# %%
df_mg_1 = pd.merge(df_1, df_host_2, on="_id")
df_mg_2 = pd.merge(df_mg_1, df_address_1, on="_id")
df_mg_3 = pd.merge(df_mg_2, df_available_1, on="_id")
df_mg_4 = pd.merge(df_mg_3, df_amenities, on="_id")
df_mg_4
# Out:
#            _id                            listing_url  \
# 0      1003530   https://www.airbnb.com/rooms/1003530
# 1     10133554  https://www.airbnb.com/rooms/10133554
# 2     10059872  https://www.airbnb.com/rooms/10059872
# 3     10084023  https://www.airbnb.com/rooms/10084023
# 4     10091713  https://www.airbnb.com/rooms/10091713
# ...        ...                                    ...
# 5550   9985696   https://www.airbnb.com/rooms/9985696
# 5551   9993190   https://www.airbnb.com/rooms/9993190
# 5552   9887054   https://www.airbnb.com/rooms/9887054
# 5553   9907907   https://www.airbnb.com/rooms/9907907
# 5554   9936016   https://www.airbnb.com/rooms/9936016
#
#                                                    name      property_type  \
# 0                   New York City - Upper West Side Apt          Apartment
# 1                   Double and triple rooms Blue mosque  Bed and breakfast
# 2                    Soho Cozy, Spacious and Convenient          Apartment
# 3                     City center private room with bed         Guesthouse
# 4      Surry Hills Studio - Your Perfect Base in Sydney          Apartment
# ...                                                 ...                ...
# 5550                                    Kadıköy-Altıyol              House
# 5551  Just Steps from the Ocean at Premier Platinum ...          Townhouse
# 5552                Quarry Bay fully furnished studio C          Apartment
# 5553                         Large double room in Bondi          Apartment
# 5554                        Alugo Apartamento na Tijuca          Apartment
#
#             room_type  bed_type  minimum_nights  maximum_nights  \
# 0        Private room  Real Bed              12             360
# 1        Private room  Real Bed               1            1125
# 2     Entire home/apt  Real Bed               4              20
# 3        Private room     Futon               1             500
# 4     Entire home/apt  Real Bed              10              21
# ...               ...       ...             ...             ...
# 5550  Entire home/apt  Real Bed               1            1125
# 5551  Entire home/apt  Real Bed               3             365
# 5552     Private room  Real Bed               3            1125
# 5553     Private room  Real Bed               3            1125
# 5554  Entire home/apt  Real Bed               1            1125
#
#               cancellation_policy  accommodates  ...  country_code  \
# 0     strict_14_with_grace_period             2  ...            US
# 1                        moderate             3  ...            TR
# 2                        flexible             3  ...            HK
# 3     strict_14_with_grace_period             1  ...            HK
# 4     strict_14_with_grace_period             2  ...            AU
# ...                           ...           ...  ...           ...
# 5550                     flexible             2  ...            TR
# 5551  strict_14_with_grace_period             6  ...            US
# 5552                     flexible             1  ...            HK
# 5553                     moderate             2  ...            AU
# 5554                     flexible             6  ...            BR
#
#       location_type   longitude   latitude  is_location_exact  \
# 0             Point  -73.965230  40.799620                 No
# 1             Point   28.980090  41.006200                 No
# 2             Point  114.150270  22.281580                Yes
# 3             Point  114.166900  22.331400                Yes
# 4             Point  151.215540 -33.880290                Yes
# ...             ...         ...        ...                ...
# 5550          Point   29.030790  40.985630                 No
# 5551          Point -156.667520  20.858940                 No
# 5552          Point  114.207220  22.291570                 No
# 5553          Point  151.265420 -33.892980                 No
# 5554          Point  -43.173761 -22.908336                 No
#
#       availability_30  availability_60  availability_90 availability_365  \
# 0                   0                0                0               93
# 1                  30               60               90              365
# 2                   0                0                0                0
# 3                  14               24               40              220
# 4                   0                0                0                0
# ...               ...              ...              ...              ...
# 5550               30               60               90              365
# 5551                0                8               31              258
# 5552               18               48               78              353
# 5553                0                0                0                0
# 5554                0                0                0                0
#
#                                               amenities
# 0     [Air conditioning, Buzzer/wireless intercom, D...
# 1     [Air conditioning, Building staff, Dryer, Esse...
# 2     [24-hour check-in, Air conditioning, Doorman, ...
# 3     [Air conditioning, Dishes and silverware, Elev...
# 4     [Bed linens, Dryer, Elevator, Essentials, Ethe...
# ...                                                 ...
# 5550  [Buzzer/wireless intercom, Cable TV, Dryer, Es...
# 5551  [Air conditioning, Dryer, Essentials, Family/k...
# 5552  [24-hour check-in, Air conditioning, Elevator,...
# 5553  [Dryer, Essentials, Hangers, Internet, Kitchen...
# 5554  [Air conditioning, Buzzer/wireless intercom, C...
#
# [5555 rows x 50 columns]

# %%
pd.set_option('display.max_columns', None)
df_mg_4
# Out:
#            _id                            listing_url  \
# 0      1003530   https://www.airbnb.com/rooms/1003530
# 1     10133554  https://www.airbnb.com/rooms/10133554
# 2     10059872  https://www.airbnb.com/rooms/10059872
# 3     10084023  https://www.airbnb.com/rooms/10084023
# 4     10091713  https://www.airbnb.com/rooms/10091713
# ...        ...                                    ...
# 5550   9985696   https://www.airbnb.com/rooms/9985696
# 5551   9993190   https://www.airbnb.com/rooms/9993190
# 5552   9887054   https://www.airbnb.com/rooms/9887054
# 5553   9907907   https://www.airbnb.com/rooms/9907907
# 5554   9936016   https://www.airbnb.com/rooms/9936016
#
#                                                    name      property_type  \
# 0                   New York City - Upper West Side Apt          Apartment
# 1                   Double and triple rooms Blue mosque  Bed and breakfast
# 2                    Soho Cozy, Spacious and Convenient          Apartment
# 3                     City center private room with bed         Guesthouse
# 4      Surry Hills Studio - Your Perfect Base in Sydney          Apartment
# ...                                                 ...                ...
# 5550                                    Kadıköy-Altıyol              House
# 5551  Just Steps from the Ocean at Premier Platinum ...          Townhouse
# 5552                Quarry Bay fully furnished studio C          Apartment
# 5553                         Large double room in Bondi          Apartment
# 5554                        Alugo Apartamento na Tijuca          Apartment
#
#             room_type  bed_type  minimum_nights  maximum_nights  \
# 0        Private room  Real Bed              12             360
# 1        Private room  Real Bed               1            1125
# 2     Entire home/apt  Real Bed               4              20
# 3        Private room     Futon               1             500
# 4     Entire home/apt  Real Bed              10              21
# ...               ...       ...             ...             ...
# 5550  Entire home/apt  Real Bed               1            1125
# 5551  Entire home/apt  Real Bed               3             365
# 5552     Private room  Real Bed               3            1125
# 5553     Private room  Real Bed               3            1125
# 5554  Entire home/apt  Real Bed               1            1125
#
#               cancellation_policy  accommodates  bedrooms  beds  \
# 0     strict_14_with_grace_period             2         1     1
# 1                        moderate             3         1     2
# 2                        flexible             3         1     2
# 3     strict_14_with_grace_period             1         1     1
# 4     strict_14_with_grace_period             2         0     1
# ...                           ...           ...       ...   ...
# 5550                     flexible             2         2     3
# 5551  strict_14_with_grace_period             6         2     4
# 5552                     flexible             1         1     1
# 5553                     moderate             2         1     1
# 5554                     flexible             6         1     2
#
#       number_of_reviews  bathrooms  price  cleaning_fee  extra_people  \
# 0                    70          1    135           135             0
# 1                    29          1    121             0             0
# 2                     3          1    699             0             0
# 3                    81          1    181            50           100
# 4                    64          1    181            50             0
# ...                 ...        ...    ...           ...           ...
# 5550                  0          1    501             0             0
# 5551                 15          2    220           315             0
# 5552                  4          1    400             0           300
# 5553                  0          1     60            50            50
# 5554                  0          2    750             0             0
#
#       guests_included                                             images  \
# 0                   1  https://a0.muscache.com/im/pictures/15074036/a...
# 1                   1  https://a0.muscache.com/im/pictures/68de30b5-e...
# 2                   1  https://a0.muscache.com/im/pictures/4533a1dc-6...
# 3                   1  https://a0.muscache.com/im/pictures/e6275515-7...
# 4                   1  https://a0.muscache.com/im/pictures/f8eaba4e-d...
# ...               ...                                                ...
# 5550                1  https://a0.muscache.com/im/pictures/e40d18b2-1...
# 5551                1  https://a0.muscache.com/im/pictures/be1978c5-6...
# 5552                2  https://a0.muscache.com/im/pictures/a39e3f36-9...
# 5553                2  https://a0.muscache.com/im/pictures/17a8857a-6...
# 5554                1  https://a0.muscache.com/im/pictures/9d939095-f...
#
#       review_scores   host_id                                    host_url  \
# 0                94    454250    https://www.airbnb.com/users/show/454250
# 1                92  52004703  https://www.airbnb.com/users/show/52004703
# 2               100  51624384  https://www.airbnb.com/users/show/51624384
# 3                92  51744313  https://www.airbnb.com/users/show/51744313
# 4                95  13764143  https://www.airbnb.com/users/show/13764143
# ...             ...       ...                                         ...
# 5550              0  51303748  https://www.airbnb.com/users/show/51303748
# 5551             92  51013381  https://www.airbnb.com/users/show/51013381
# 5552             85  31386255  https://www.airbnb.com/users/show/31386255
# 5553              0  47615848  https://www.airbnb.com/users/show/47615848
# 5554              0  47092481  https://www.airbnb.com/users/show/47092481
#
#            host_name                            host_location  \
# 0              Greta        New York, New York, United States
# 1        Mehmet Emin               Istanbul, İstanbul, Turkey
# 2           Giovanni                     Hong Kong, Hong Kong
# 3                 Yi                            United States
# 4                Ben               New South Wales, Australia
# ...              ...                                      ...
# 5550            Eren               Kadikoy, Çanakkale, Turkey
# 5551  Coconut Condos           Lahaina, Hawaii, United States
# 5552             Cat                                Hong Kong
# 5553            Lucy  Bondi Beach, New South Wales, Australia
# 5554          Aliane                                       BR
#
#       host_response_time                                 host_thumbnail_url  \
# 0         within an hour  https://a0.muscache.com/im/pictures/f1022be4-e...
# 1     within a few hours  https://a0.muscache.com/im/pictures/user/4cb6b...
# 2          Not Specified  https://a0.muscache.com/im/pictures/264b82a7-7...
# 3         within an hour  https://a0.muscache.com/im/pictures/user/a204d...
# 4          Not Specified  https://a0.muscache.com/im/pictures/03c4d82b-7...
# ...                  ...                                                ...
# 5550       Not Specified  https://a0.muscache.com/im/pictures/89a1b839-2...
# 5551      within an hour  https://a0.muscache.com/im/pictures/fa071e13-8...
# 5552        within a day  https://a0.muscache.com/im/pictures/965f2c12-5...
# 5553       Not Specified  https://a0.muscache.com/im/pictures/b4675d0a-f...
# 5554       Not Specified  https://a0.muscache.com/im/pictures/4b17fc8e-4...
#
#                                        host_picture_url host_neighbourhood  \
# 0     https://a0.muscache.com/im/pictures/f1022be4-e...      Not Specified
# 1     https://a0.muscache.com/im/pictures/user/4cb6b...      Not Specified
# 2     https://a0.muscache.com/im/pictures/264b82a7-7...               Soho
# 3     https://a0.muscache.com/im/pictures/user/a204d...       Shek Kip Mei
# 4     https://a0.muscache.com/im/pictures/03c4d82b-7...        Surry Hills
# ...                                                 ...                ...
# 5550  https://a0.muscache.com/im/pictures/89a1b839-2...      Not Specified
# 5551  https://a0.muscache.com/im/pictures/fa071e13-8...      Not Specified
# 5552  https://a0.muscache.com/im/pictures/965f2c12-5...       Causeway Bay
# 5553  https://a0.muscache.com/im/pictures/b4675d0a-f...      Not Specified
# 5554  https://a0.muscache.com/im/pictures/4b17fc8e-4...      Not Specified
#
#      host_response_rate host_is_superhost host_has_profile_pic  \
# 0                 100.0               Yes                  Yes
# 1                 100.0                No                  Yes
# 2         Not Specified                No                  Yes
# 3                 100.0                No                  Yes
# 4         Not Specified                No                  Yes
# ...                 ...               ...                  ...
# 5550      Not Specified                No                  Yes
# 5551               99.0                No                  Yes
# 5552               60.0                No                  Yes
# 5553      Not Specified                No                  Yes
# 5554      Not Specified                No                  Yes
#
#      host_identity_verified  host_listings_count  host_total_listings_count  \
# 0                       Yes                    3                          3
# 1                       Yes                    2                          2
# 2                        No                    1                          1
# 3                       Yes                    2                          2
# 4                       Yes                    1                          1
# ...                     ...                  ...                        ...
# 5550                     No                    2                          2
# 5551                    Yes                   58                         58
# 5552                     No                    7                          7
# 5553                     No                    1                          1
# 5554                     No                    1                          1
#
#                                      host_verifications  \
# 0     [email, phone, reviews, jumio, offline_governm...
# 1     [email, phone, facebook, reviews, jumio, offli...
# 2         [email, phone, reviews, jumio, government_id]
# 3     [email, phone, reviews, jumio, offline_governm...
# 4     [email, phone, google, reviews, jumio, offline...
# ...                                                 ...
# 5550                                     [email, phone]
# 5551           [email, phone, reviews, kba, work_email]
# 5552                            [email, phone, reviews]
# 5553                                     [email, phone]
# 5554                                            [phone]
#
#                                       street                      suburb  \
# 0                New York, NY, United States                   Manhattan
# 1                   Fatih , İstanbul, Turkey                       Fatih
# 2     Hong Kong, Hong Kong Island, Hong Kong  Central & Western District
# 3                  Hong Kong , 九龍, Hong Kong       Sham Shui Po District
# 4                Surry Hills, NSW, Australia                Darlinghurst
# ...                                      ...                         ...
# 5550               Kadıköy, İstanbul, Turkey                        Moda
# 5551              Lahaina, HI, United States                     Lahaina
# 5552  Hong Kong, Hong Kong Island, Hong Kong                  Quarry Bay
# 5553             Bondi Beach, NSW, Australia                       Bondi
# 5554  Rio de Janeiro, Rio de Janeiro, Brazil                        Lapa
#
#         government_area          market        country country_code  \
# 0       Upper West Side        New York  United States           US
# 1                 Fatih        Istanbul         Turkey           TR
# 2     Central & Western       Hong Kong      Hong Kong           HK
# 3          Sham Shui Po       Hong Kong      Hong Kong           HK
# 4                Sydney          Sydney      Australia           AU
# ...                 ...             ...            ...          ...
# 5550            Kadikoy        Istanbul         Turkey           TR
# 5551            Lahaina            Maui  United States           US
# 5552            Eastern       Hong Kong      Hong Kong           HK
# 5553           Waverley          Sydney      Australia           AU
# 5554             Centro  Rio De Janeiro         Brazil           BR
#
#      location_type   longitude   latitude is_location_exact  availability_30  \
# 0            Point  -73.965230  40.799620                No                0
# 1            Point   28.980090  41.006200                No               30
# 2            Point  114.150270  22.281580               Yes                0
# 3            Point  114.166900  22.331400               Yes               14
# 4            Point  151.215540 -33.880290               Yes                0
# ...            ...         ...        ...               ...              ...
# 5550         Point   29.030790  40.985630                No               30
# 5551         Point -156.667520  20.858940                No                0
# 5552         Point  114.207220  22.291570                No               18
# 5553         Point  151.265420 -33.892980                No                0
# 5554         Point  -43.173761 -22.908336                No                0
#
#       availability_60  availability_90  availability_365  \
# 0                   0                0                93
# 1                  60               90               365
# 2                   0                0                 0
# 3                  24               40               220
# 4                   0                0                 0
# ...               ...              ...               ...
# 5550               60               90               365
# 5551                8               31               258
# 5552               48               78               353
# 5553                0                0                 0
# 5554                0                0                 0
#
#                                               amenities
# 0     [Air conditioning, Buzzer/wireless intercom, D...
# 1     [Air conditioning, Building staff, Dryer, Esse...
# 2     [24-hour check-in, Air conditioning, Doorman, ...
# 3     [Air conditioning, Dishes and silverware, Elev...
# 4     [Bed linens, Dryer, Elevator, Essentials, Ethe...
# ...                                                 ...
# 5550  [Buzzer/wireless intercom, Cable TV, Dryer, Es...
# 5551  [Air conditioning, Dryer, Essentials, Family/k...
# 5552  [24-hour check-in, Air conditioning, Elevator,...
# 5553  [Dryer, Essentials, Hangers, Internet, Kitchen...
# 5554  [Air conditioning, Buzzer/wireless intercom, C...
#
# [5555 rows x 50 columns]

# %%
df_mg_4.to_csv("airbnb_data_cleaned.csv", index=False)

# %%
df = pd.read_csv(r"C:\datascience\guvi_projects\guvi-airbnb-project\airbnb_data_cleaned.csv")

# %%
df
# Out:
#            _id                            listing_url  \
# 0      1003530   https://www.airbnb.com/rooms/1003530
# 1     10133554  https://www.airbnb.com/rooms/10133554
# 2     10059872  https://www.airbnb.com/rooms/10059872
# 3     10084023  https://www.airbnb.com/rooms/10084023
# 4     10091713  https://www.airbnb.com/rooms/10091713
# ...        ...                                    ...
# 5550   9985696   https://www.airbnb.com/rooms/9985696
# 5551   9993190   https://www.airbnb.com/rooms/9993190
# 5552   9887054   https://www.airbnb.com/rooms/9887054
# 5553   9907907   https://www.airbnb.com/rooms/9907907
# 5554   9936016   https://www.airbnb.com/rooms/9936016
#
#                                                    name      property_type  \
# 0                   New York City - Upper West Side Apt          Apartment
# 1                   Double and triple rooms Blue mosque  Bed and breakfast
# 2                    Soho Cozy, Spacious and Convenient          Apartment
# 3                     City center private room with bed         Guesthouse
# 4      Surry Hills Studio - Your Perfect Base in Sydney          Apartment
# ...                                                 ...                ...
# 5550                                    Kadıköy-Altıyol              House
# 5551  Just Steps from the Ocean at Premier Platinum ...          Townhouse
# 5552                Quarry Bay fully furnished studio C          Apartment
# 5553                         Large double room in Bondi          Apartment
# 5554                        Alugo Apartamento na Tijuca          Apartment
#
#             room_type  bed_type  minimum_nights  maximum_nights  \
# 0        Private room  Real Bed              12             360
# 1        Private room  Real Bed               1            1125
# 2     Entire home/apt  Real Bed               4              20
# 3        Private room     Futon               1             500
# 4     Entire home/apt  Real Bed              10              21
# ...               ...       ...             ...             ...
# 5550  Entire home/apt  Real Bed               1            1125
# 5551  Entire home/apt  Real Bed               3             365
# 5552     Private room  Real Bed               3            1125
# 5553     Private room  Real Bed               3            1125
# 5554  Entire home/apt  Real Bed               1            1125
#
#               cancellation_policy  accommodates  bedrooms  beds  \
# 0     strict_14_with_grace_period             2         1     1
# 1                        moderate             3         1     2
# 2                        flexible             3         1     2
# 3     strict_14_with_grace_period             1         1     1
# 4     strict_14_with_grace_period             2         0     1
# ...                           ...           ...       ...   ...
# 5550                     flexible             2         2     3
# 5551  strict_14_with_grace_period             6         2     4
# 5552                     flexible             1         1     1
# 5553                     moderate             2         1     1
# 5554                     flexible             6         1     2
#
#       number_of_reviews  bathrooms  price  cleaning_fee  extra_people  \
# 0                    70          1    135           135             0
# 1                    29          1    121             0             0
# 2                     3          1    699             0             0
# 3                    81          1    181            50           100
# 4                    64          1    181            50             0
# ...                 ...        ...    ...           ...           ...
# 5550                  0          1    501             0             0
# 5551                 15          2    220           315             0
# 5552                  4          1    400             0           300
# 5553                  0          1     60            50            50
# 5554                  0          2    750             0             0
#
#       guests_included                                             images  \
# 0                   1  https://a0.muscache.com/im/pictures/15074036/a...
# 1                   1  https://a0.muscache.com/im/pictures/68de30b5-e...
# 2                   1  https://a0.muscache.com/im/pictures/4533a1dc-6...
# 3                   1  https://a0.muscache.com/im/pictures/e6275515-7...
# 4                   1  https://a0.muscache.com/im/pictures/f8eaba4e-d...
# ...               ...                                                ...
# 5550                1  https://a0.muscache.com/im/pictures/e40d18b2-1...
# 5551                1  https://a0.muscache.com/im/pictures/be1978c5-6...
# 5552                2  https://a0.muscache.com/im/pictures/a39e3f36-9...
# 5553                2  https://a0.muscache.com/im/pictures/17a8857a-6...
# 5554                1  https://a0.muscache.com/im/pictures/9d939095-f...
#
#       review_scores   host_id                                    host_url  \
# 0                94    454250    https://www.airbnb.com/users/show/454250
# 1                92  52004703  https://www.airbnb.com/users/show/52004703
# 2               100  51624384  https://www.airbnb.com/users/show/51624384
# 3                92  51744313  https://www.airbnb.com/users/show/51744313
# 4                95  13764143  https://www.airbnb.com/users/show/13764143
# ...             ...       ...                                         ...
# 5550              0  51303748  https://www.airbnb.com/users/show/51303748
# 5551             92  51013381  https://www.airbnb.com/users/show/51013381
# 5552             85  31386255  https://www.airbnb.com/users/show/31386255
# 5553              0  47615848  https://www.airbnb.com/users/show/47615848
# 5554              0  47092481  https://www.airbnb.com/users/show/47092481
#
#            host_name                            host_location  \
# 0              Greta        New York, New York, United States
# 1        Mehmet Emin               Istanbul, İstanbul, Turkey
# 2           Giovanni                     Hong Kong, Hong Kong
# 3                 Yi                            United States
# 4                Ben               New South Wales, Australia
# ...              ...                                      ...
# 5550            Eren               Kadikoy, Çanakkale, Turkey
# 5551  Coconut Condos           Lahaina, Hawaii, United States
# 5552             Cat                                Hong Kong
# 5553            Lucy  Bondi Beach, New South Wales, Australia
# 5554          Aliane                                       BR
#
#       host_response_time                                 host_thumbnail_url  \
# 0         within an hour  https://a0.muscache.com/im/pictures/f1022be4-e...
# 1     within a few hours  https://a0.muscache.com/im/pictures/user/4cb6b...
# 2          Not Specified  https://a0.muscache.com/im/pictures/264b82a7-7...
# 3         within an hour  https://a0.muscache.com/im/pictures/user/a204d...
# 4          Not Specified  https://a0.muscache.com/im/pictures/03c4d82b-7...
# ...                  ...                                                ...
# 5550       Not Specified  https://a0.muscache.com/im/pictures/89a1b839-2...
# 5551      within an hour  https://a0.muscache.com/im/pictures/fa071e13-8...
# 5552        within a day  https://a0.muscache.com/im/pictures/965f2c12-5...
# 5553       Not Specified  https://a0.muscache.com/im/pictures/b4675d0a-f...
# 5554       Not Specified  https://a0.muscache.com/im/pictures/4b17fc8e-4...
#
#                                        host_picture_url host_neighbourhood  \
# 0     https://a0.muscache.com/im/pictures/f1022be4-e...      Not Specified
# 1     https://a0.muscache.com/im/pictures/user/4cb6b...      Not Specified
# 2     https://a0.muscache.com/im/pictures/264b82a7-7...               Soho
# 3     https://a0.muscache.com/im/pictures/user/a204d...       Shek Kip Mei
# 4     https://a0.muscache.com/im/pictures/03c4d82b-7...        Surry Hills
# ...                                                 ...                ...
# 5550  https://a0.muscache.com/im/pictures/89a1b839-2...      Not Specified
# 5551  https://a0.muscache.com/im/pictures/fa071e13-8...      Not Specified
# 5552  https://a0.muscache.com/im/pictures/965f2c12-5...       Causeway Bay
# 5553  https://a0.muscache.com/im/pictures/b4675d0a-f...      Not Specified
# 5554  https://a0.muscache.com/im/pictures/4b17fc8e-4...      Not Specified
#
#      host_response_rate host_is_superhost host_has_profile_pic  \
# 0                 100.0               Yes                  Yes
# 1                 100.0                No                  Yes
# 2         Not Specified                No                  Yes
# 3                 100.0                No                  Yes
# 4         Not Specified                No                  Yes
# ...                 ...               ...                  ...
# 5550      Not Specified                No                  Yes
# 5551               99.0                No                  Yes
# 5552               60.0                No                  Yes
# 5553      Not Specified                No                  Yes
# 5554      Not Specified                No                  Yes
#
#      host_identity_verified  host_listings_count  host_total_listings_count  \
# 0                       Yes                    3                          3
# 1                       Yes                    2                          2
# 2                        No                    1                          1
# 3                       Yes                    2                          2
# 4                       Yes                    1                          1
# ...                     ...                  ...                        ...
# 5550                     No                    2                          2
# 5551                    Yes                   58                         58
# 5552                     No                    7                          7
# 5553                     No                    1                          1
# 5554                     No                    1                          1
#
#                                      host_verifications  \
# 0     ['email', 'phone', 'reviews', 'jumio', 'offlin...
# 1     ['email', 'phone', 'facebook', 'reviews', 'jum...
# 2     ['email', 'phone', 'reviews', 'jumio', 'govern...
# 3     ['email', 'phone', 'reviews', 'jumio', 'offlin...
# 4     ['email', 'phone', 'google', 'reviews', 'jumio...
# ...                                                 ...
# 5550                                 ['email', 'phone']
# 5551  ['email', 'phone', 'reviews', 'kba', 'work_ema...
# 5552                      ['email', 'phone', 'reviews']
# 5553                                 ['email', 'phone']
# 5554                                          ['phone']
#
#                                       street                      suburb  \
# 0                New York, NY, United States                   Manhattan
# 1                   Fatih , İstanbul, Turkey                       Fatih
# 2     Hong Kong, Hong Kong Island, Hong Kong  Central & Western District
# 3                  Hong Kong , 九龍, Hong Kong       Sham Shui Po District
# 4                Surry Hills, NSW, Australia                Darlinghurst
# ...                                      ...                         ...
# 5550               Kadıköy, İstanbul, Turkey                        Moda
# 5551              Lahaina, HI, United States                     Lahaina
# 5552  Hong Kong, Hong Kong Island, Hong Kong                  Quarry Bay
# 5553             Bondi Beach, NSW, Australia                       Bondi
# 5554  Rio de Janeiro, Rio de Janeiro, Brazil                        Lapa
#
#         government_area          market        country country_code  \
# 0       Upper West Side        New York  United States           US
# 1                 Fatih        Istanbul         Turkey           TR
# 2     Central & Western       Hong Kong      Hong Kong           HK
# 3          Sham Shui Po       Hong Kong      Hong Kong           HK
# 4                Sydney          Sydney      Australia           AU
# ...                 ...             ...            ...          ...
# 5550            Kadikoy        Istanbul         Turkey           TR
# 5551            Lahaina            Maui  United States           US
# 5552            Eastern       Hong Kong      Hong Kong           HK
# 5553           Waverley          Sydney      Australia           AU
# 5554             Centro  Rio De Janeiro         Brazil           BR
#
#      location_type   longitude   latitude is_location_exact  availability_30  \
# 0            Point  -73.965230  40.799620                No                0
# 1            Point   28.980090  41.006200                No               30
# 2            Point  114.150270  22.281580               Yes                0
# 3            Point  114.166900  22.331400               Yes               14
# 4            Point  151.215540 -33.880290               Yes                0
# ...            ...         ...        ...               ...              ...
# 5550         Point   29.030790  40.985630                No               30
# 5551         Point -156.667520  20.858940                No                0
# 5552         Point  114.207220  22.291570                No               18
# 5553         Point  151.265420 -33.892980                No                0
# 5554         Point  -43.173761 -22.908336                No                0
#
#       availability_60  availability_90  availability_365  \
# 0                   0                0                93
# 1                  60               90               365
# 2                   0                0                 0
# 3                  24               40               220
# 4                   0                0                 0
# ...               ...              ...               ...
# 5550               60               90               365
# 5551                8               31               258
# 5552               48               78               353
# 5553                0                0                 0
# 5554                0                0                 0
#
#                                               amenities
# 0     ['Air conditioning', 'Buzzer/wireless intercom...
# 1     ['Air conditioning', 'Building staff', 'Dryer'...
# 2     ['24-hour check-in', 'Air conditioning', 'Door...
# 3     ['Air conditioning', 'Dishes and silverware', ...
# 4     ['Bed linens', 'Dryer', 'Elevator', 'Essential...
# ...                                                 ...
# 5550  ['Buzzer/wireless intercom', 'Cable TV', 'Drye...
# 5551  ['Air conditioning', 'Dryer', 'Essentials', 'F...
# 5552  ['24-hour check-in', 'Air conditioning', 'Elev...
# 5553  ['Dryer', 'Essentials', 'Hangers', 'Internet',...
# 5554  ['Air conditioning', 'Buzzer/wireless intercom...
#
# [5555 rows x 50 columns]

# %%
df["country"].unique()
# Out:
# array(['United States', 'Turkey', 'Hong Kong', 'Australia', 'Portugal',
#        'Brazil', 'Canada', 'Spain', 'China'], dtype=object)

# %%
df1 = df[df["country"] == "Brazil"]
df1.reset_index(drop=True, inplace=True)

# %%
df2 = df1[df1["room_type"] == "Private room"]
df2.reset_index(drop=True, inplace=True)

# %%
df2
# Out:
#           _id                            listing_url  \
# 0    10051164  https://www.airbnb.com/rooms/10051164
# 1    10030955  https://www.airbnb.com/rooms/10030955
# 2    10228731  https://www.airbnb.com/rooms/10228731
# 3    10299095  https://www.airbnb.com/rooms/10299095
# 4    10471178  https://www.airbnb.com/rooms/10471178
# ..        ...                                    ...
# 160   9667647   https://www.airbnb.com/rooms/9667647
# 161   9643051   https://www.airbnb.com/rooms/9643051
# 162   9765083   https://www.airbnb.com/rooms/9765083
# 163   9987200   https://www.airbnb.com/rooms/9987200
# 164   9951865   https://www.airbnb.com/rooms/9951865
#
#                                               name      property_type  \
# 0               Catete's Colonial Big Hause Room B              House
# 1                      Apt Linda Vista Lagoa - Rio          Apartment
# 2                         Quarto inteiro na Tijuca          Apartment
# 3    Small Room w Bathroom Flamengo Rio de Janeiro          Apartment
# 4                                      Rented Room          Apartment
# ..                                             ...                ...
# 160              Ótimo sala e quarta e dependência          Apartment
# 161            Private room with great breakfast 3  Bed and breakfast
# 162                    House in a charming village              House
# 163   The best suite in Copacabana (total privacy)         Aparthotel
# 164                                   Quarto Legal          Apartment
#
#         room_type  bed_type  minimum_nights  maximum_nights  \
# 0    Private room  Real Bed               2            1125
# 1    Private room  Real Bed               1            1125
# 2    Private room  Real Bed               1              15
# 3    Private room  Real Bed               4            1125
# 4    Private room  Real Bed               1            1125
# ..            ...       ...             ...             ...
# 160  Private room  Real Bed               1            1125
# 161  Private room  Real Bed               2            1125
# 162  Private room  Real Bed               7            1125
# 163  Private room  Real Bed               3              60
# 164  Private room  Real Bed               2              15
#
#              cancellation_policy  accommodates  bedrooms  beds  \
# 0    strict_14_with_grace_period             8         1     8
# 1                       flexible             2         1     1
# 2                       flexible             1         1     1
# 3                       moderate             1         1     1
# 4                       flexible             1         1     1
# ..                           ...           ...       ...   ...
# 160                     flexible             3         1     2
# 161  strict_14_with_grace_period             2         1     1
# 162                     flexible             2         1     1
# 163                     flexible             3         1     3
# 164                     moderate             1         1     1
#
#      number_of_reviews  bathrooms  price  cleaning_fee  extra_people  \
# 0                    1          4    250             0            40
# 1                    0          2    701           250             0
# 2                    1          2    149            30             0
# 3                    1          1     71            20             0
# 4                    0          1    112             0             0
# ..                 ...        ...    ...           ...           ...
# 160                  1          1    198            19             0
# 161                 29          2    131             0            30
# 162                  0          1    351             0             0
# 163                 90          1    101           100            50
# 164                  1          1    101            50             0
#
#      guests_included                                             images  \
# 0                  4  https://a0.muscache.com/im/pictures/b2119f25-4...
# 1                  1  https://a0.muscache.com/im/pictures/59c516bd-c...
# 2                  1  https://a0.muscache.com/im/pictures/de6ab94d-9...
# 3                  1  https://a0.muscache.com/im/pictures/26459098-5...
# 4                  1  https://a0.muscache.com/im/pictures/fc7aaab6-2...
# ..               ...                                                ...
# 160                1  https://a0.muscache.com/im/pictures/632a7dc1-3...
# 161                1  https://a0.muscache.com/im/pictures/10859ffc-3...
# 162                1  https://a0.muscache.com/im/pictures/a51e6ddb-2...
# 163                2  https://a0.muscache.com/im/pictures/4a2a03e4-d...
# 164                1  https://a0.muscache.com/im/pictures/43719c6f-2...
#
#      review_scores   host_id                                    host_url  \
# 0               80  51326285  https://www.airbnb.com/users/show/51326285
# 1                0  51496939  https://www.airbnb.com/users/show/51496939
# 2              100  12673423  https://www.airbnb.com/users/show/12673423
# 3               80  52988408  https://www.airbnb.com/users/show/52988408
# 4                0  53957975  https://www.airbnb.com/users/show/53957975
# ..             ...       ...                                         ...
# 160             60  49959766  https://www.airbnb.com/users/show/49959766
# 161             99  10790369  https://www.airbnb.com/users/show/10790369
# 162              0  50352113  https://www.airbnb.com/users/show/50352113
# 163             97  51314789  https://www.airbnb.com/users/show/51314789
# 164            100  51142039  https://www.airbnb.com/users/show/51142039
#
#      host_name                                    host_location  \
# 0      Beatriz  Rio de Janeiro, State of Rio de Janeiro, Brazil
# 1        Livia                                               BR
# 2     Gilberto                      Rio, Rio de Janeiro, Brazil
# 3     Fernanda                                               BR
# 4    Jercilene              São Gonçalo, Rio de Janeiro, Brazil
# ..         ...                                              ...
# 160     Kamila  Rio de Janeiro, State of Rio de Janeiro, Brazil
# 161        Ewa                      Rio, Rio de Janeiro, Brazil
# 162       Luiz                                               BR
# 163     Dumont  Rio de Janeiro, State of Rio de Janeiro, Brazil
# 164    Dailton  Rio de Janeiro, State of Rio de Janeiro, Brazil
#
#      host_response_time                                 host_thumbnail_url  \
# 0        within an hour  https://a0.muscache.com/im/pictures/eb09c9cb-b...
# 1         Not Specified  https://a0.muscache.com/im/pictures/b7911710-9...
# 2         Not Specified  https://a0.muscache.com/im/users/12673423/prof...
# 3         Not Specified  https://a0.muscache.com/im/pictures/0c78bdd8-1...
# 4    a few days or more  https://a0.muscache.com/im/pictures/191ca5bb-2...
# ..                  ...                                                ...
# 160       Not Specified  https://a0.muscache.com/im/pictures/43fd18f7-8...
# 161      within an hour  https://a0.muscache.com/im/users/10790369/prof...
# 162       Not Specified  https://a0.muscache.com/im/pictures/3c441510-e...
# 163      within an hour  https://a0.muscache.com/im/pictures/65582ca0-8...
# 164  within a few hours  https://a0.muscache.com/im/pictures/user/ad3e9...
#
#                                       host_picture_url host_neighbourhood  \
# 0    https://a0.muscache.com/im/pictures/eb09c9cb-b...             Catete
# 1    https://a0.muscache.com/im/pictures/b7911710-9...              Lagoa
# 2    https://a0.muscache.com/im/users/12673423/prof...             Tijuca
# 3    https://a0.muscache.com/im/pictures/0c78bdd8-1...      Not Specified
# 4    https://a0.muscache.com/im/pictures/191ca5bb-2...      Not Specified
# ..                                                 ...                ...
# 160  https://a0.muscache.com/im/pictures/43fd18f7-8...      Not Specified
# 161  https://a0.muscache.com/im/users/10790369/prof...       Santa Teresa
# 162  https://a0.muscache.com/im/pictures/3c441510-e...           Flamengo
# 163  https://a0.muscache.com/im/pictures/65582ca0-8...         Copacabana
# 164  https://a0.muscache.com/im/pictures/user/ad3e9...       Rio Comprido
#
#     host_response_rate host_is_superhost host_has_profile_pic  \
# 0                 80.0                No                  Yes
# 1        Not Specified                No                  Yes
# 2        Not Specified                No                  Yes
# 3        Not Specified                No                  Yes
# 4                  0.0                No                  Yes
# ..                 ...               ...                  ...
# 160      Not Specified                No                  Yes
# 161              100.0               Yes                  Yes
# 162      Not Specified                No                  Yes
# 163              100.0               Yes                  Yes
# 164              100.0                No                  Yes
#
#     host_identity_verified  host_listings_count  host_total_listings_count  \
# 0                      Yes                    5                          5
# 1                       No                    1                          1
# 2                       No                    2                          2
# 3                       No                    2                          2
# 4                       No                    1                          1
# ..                     ...                  ...                        ...
# 160                     No                    1                          1
# 161                    Yes                    6                          6
# 162                     No                    1                          1
# 163                    Yes                    3                          3
# 164                     No                    3                          3
#
#                                     host_verifications  \
# 0    ['email', 'phone', 'facebook', 'reviews', 'jum...
# 1         ['email', 'phone', 'jumio', 'government_id']
# 2                        ['email', 'phone', 'reviews']
# 3                        ['email', 'phone', 'reviews']
# 4             ['email', 'phone', 'facebook', 'google']
# ..                                                 ...
# 160          ['email', 'phone', 'facebook', 'reviews']
# 161  ['email', 'phone', 'reviews', 'jumio', 'offlin...
# 162                                 ['email', 'phone']
# 163  ['email', 'phone', 'reviews', 'jumio', 'govern...
# 164                      ['email', 'phone', 'reviews']
#
#                                               street        suburb  \
# 0             Rio de Janeiro, Rio de Janeiro, Brazil        Catete
# 1             Rio de Janeiro, Rio de Janeiro, Brazil         Lagoa
# 2             Rio de Janeiro, Rio de Janeiro, Brazil        Tijuca
# 3             Rio de Janeiro, Rio de Janeiro, Brazil      Flamengo
# 4             Rio de Janeiro, Rio de Janeiro, Brazil      Botafogo
# ..                                               ...           ...
# 160           Rio de Janeiro, Rio de Janeiro, Brazil      Botafogo
# 161           Rio de Janeiro, Rio de Janeiro, Brazil  Santa Teresa
# 162           Rio de Janeiro, Rio de Janeiro, Brazil      Flamengo
# 163           Rio de Janeiro, Rio de Janeiro, Brazil    Copacabana
# 164  Rio de Janeiro, State of Rio de Janeiro, Brazil        Tijuca
#
#     government_area          market country country_code location_type  \
# 0            Catete  Rio De Janeiro  Brazil           BR         Point
# 1             Lagoa  Rio De Janeiro  Brazil           BR         Point
# 2            Tijuca  Rio De Janeiro  Brazil           BR         Point
# 3          Flamengo  Rio De Janeiro  Brazil           BR         Point
# 4          Botafogo  Rio De Janeiro  Brazil           BR         Point
# ..              ...             ...     ...          ...           ...
# 160        Botafogo  Rio De Janeiro  Brazil           BR         Point
# 161    Santa Teresa  Rio De Janeiro  Brazil           BR         Point
# 162        Flamengo  Rio De Janeiro  Brazil           BR         Point
# 163      Copacabana  Rio De Janeiro  Brazil           BR         Point
# 164    Rio Comprido  Rio De Janeiro  Brazil           BR         Point
#
#      longitude   latitude is_location_exact  availability_30  availability_60  \
# 0   -43.180157 -22.926382               Yes               10               10
# 1   -43.205047 -22.971951               Yes               28               58
# 2   -43.247422 -22.936203                No               28               58
# 3   -43.176451 -22.938483                No                0                0
# 4   -43.179332 -22.941321                No               30               60
# ..         ...        ...               ...              ...              ...
# 160 -43.184252 -22.943498                No                0                0
# 161 -43.189812 -22.922432               Yes               11               11
# 162 -43.175503 -22.929367               Yes                0                0
# 163 -43.176533 -22.961076               Yes                7               29
# 164 -43.210667 -22.918155                No               30               60
#
#      availability_90  availability_365  \
# 0                 21               296
# 1                 88               363
# 2                 88               178
# 3                  0                 0
# 4                 90               365
# ..               ...               ...
# 160                0                 0
# 161               11               253
# 162                0                 0
# 163               53                53
# 164               90               365
#
#                                              amenities
# 0    ['Air conditioning', 'Cable TV', 'Essentials',...
# 1    ['24-hour check-in', 'Air conditioning', 'Buzz...
# 2    ['Family/kid friendly', 'Free parking on premi...
# 3    ['Cat(s)', 'Dryer', 'Elevator', 'Essentials', ...
# 4    ['Buzzer/wireless intercom', 'Doorman', 'Dryer...
# ..                                                 ...
# 160  ['24-hour check-in', 'Air conditioning', 'Buzz...
# 161  ['24-hour check-in', 'Breakfast', 'Buzzer/wire...
# 162  ['Essentials', 'Hangers', 'Internet', 'Kitchen...
# 163  ['Air conditioning', 'Bed linens', 'Building s...
# 164  ['Elevator', 'Essentials', 'Free street parkin...
#
# [165 rows x 50 columns]

# %%
df_bar = df2.groupby("property_type").agg({"price": "sum", "number_of_reviews": "sum", "review_scores": "mean"})
df_bar.reset_index(inplace=True)

# %%
df_bar
# Out:
#              property_type  price  number_of_reviews  review_scores
# 0               Aparthotel    452                 93      95.000000
# 1                Apartment  24846               1085      47.196262
# 2        Bed and breakfast   1635                192      65.500000
# 3           Boutique hotel     86                  3     100.000000
# 4   Casa particular (Cuba)     56                  2      60.000000
# 5              Condominium    951                112      79.600000
# 6              Guest suite   1369                 15      48.500000
# 7                   Hostel   2001                  1       0.000000
# 8                    House   6608                228      36.392857
# 9                     Loft   2682                  7      49.000000
# 10      Serviced apartment    369                  7      98.500000
# 11               Townhouse    101                 64      98.000000
# 12                   Villa     41                  0       0.000000

# %%
fig_bar = px.bar(df_bar, x="property_type", y="price", title="Price for property types", hover_data=["number_of_reviews", "review_scores"], width=600, height=500, color_discrete_sequence=px.colors.sequential.Rainbow)
fig_bar.show()

# %%
df3 = df2[df1["property_type"] == "Apartment"]
df3.reset_index(drop=True, inplace=True)
# Out:
# C:\Users\ranji\AppData\Local\Temp\ipykernel_9252\929134748.py:1: UserWarning:
#
# Boolean Series key will be reindexed to match DataFrame index.

# %%
df_pie = df3.groupby("host_response_time")[["price","bedrooms"]].sum()
df_pie.reset_index(inplace=True)
